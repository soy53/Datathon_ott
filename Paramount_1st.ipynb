# %% [markdown]
# # PARAMOUNT

# %%
# Pandas, Numpy, Matplotlib, Seaborn을 호출
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('default')
import seaborn as sns

# para_credits 변수를 만들고 credits.csv 파일의 데이터를 할당
para_credits = pd.read_csv('~/aiffel/paramount/credits.csv')

# para_credits의 head 값 확인하기
para_credits.head()
# Out:
#    person_id       id             name           character   role
# 0      21174  tm19248    Buster Keaton         Johnny Gray  ACTOR
# 1      28713  tm19248      Marion Mack       Annabelle Lee  ACTOR
# 2      28714  tm19248    Glen Cavender    Captain Anderson  ACTOR
# 3      28715  tm19248       Jim Farley    General Thatcher  ACTOR
# 4      27348  tm19248  Frederick Vroom  A Southern General  ACTOR

# %%
# para_titles 변수를 만들고 titles.csv 파일의 데이터를 할당
para_titles = pd.read_csv('~/aiffel/paramount/titles.csv')

# para_titles의 head 값 확인하기
para_titles.head()
# Out:
#          id                                             title   type  \
# 0   tm19248                                       The General  MOVIE
# 1   tm83884                                   His Girl Friday  MOVIE
# 2   tm19424                                            Detour  MOVIE
# 3  tm112005                                         Marihuana  MOVIE
# 4   tm22806  Intolerance: Love's Struggle Throughout the Ages  MOVIE
#
#                                          description  release_year  \
# 0  During America’s Civil War, Union spies steal ...          1926
# 1  Hildy, the journalist former wife of newspaper...          1940
# 2  The life of Al Roberts, a pianist in a New Yor...          1945
# 3  A young girl named Burma attends a beach party...          1936
# 4  The story of a poor young woman, separated by ...          1916
#
#   age_certification  runtime  \
# 0               NaN       78
# 1               NaN       92
# 2               NaN       66
# 3               NaN       57
# 4               NaN      197
#
#                                               genres production_countries  \
# 0  ['action', 'drama', 'war', 'western', 'comedy'...               ['US']
# 1                     ['comedy', 'drama', 'romance']               ['US']
# 2                     ['thriller', 'drama', 'crime']               ['US']
# 3                                 ['crime', 'drama']               ['US']
# 4                               ['history', 'drama']               ['US']
#
#    seasons    imdb_id  imdb_score  imdb_votes  tmdb_popularity  tmdb_score
# 0      NaN  tt0017925         8.2     89766.0            8.647         8.0
# 1      NaN  tt0032599         7.8     57835.0           11.270         7.4
# 2      NaN  tt0037638         7.3     17233.0            7.757         7.2
# 3      NaN  tt0026683         4.0       864.0            3.748         3.6
# 4      NaN  tt0006864         7.7     15242.0            9.412         7.2

# %%
# para_titles의 정보 확인하기
para_titles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2825 entries, 0 to 2824
# Data columns (total 15 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    2825 non-null   object
#  1   title                 2825 non-null   object
#  2   type                  2825 non-null   object
#  3   description           2812 non-null   object
#  4   release_year          2825 non-null   int64
#  5   age_certification     1302 non-null   object
#  6   runtime               2825 non-null   int64
#  7   genres                2825 non-null   object
#  8   production_countries  2825 non-null   object
#  9   seasons               626 non-null    float64
#  10  imdb_id               2666 non-null   object
#  11  imdb_score            2613 non-null   float64
#  12  imdb_votes            2613 non-null   float64
#  13  tmdb_popularity       2768 non-null   float64
#  14  tmdb_score            2337 non-null   float64
# dtypes: float64(5), int64(2), object(8)
# memory usage: 331.2+ KB

# %%
para_titles.shape
# Out:
# (2825, 15)

# %%
# 컬럼별 결측치 확인
para_titles.isnull().sum()
# Out:
# id                         0
# title                      0
# type                       0
# description               13
# release_year               0
# age_certification       1523
# runtime                    0
# genres                     0
# production_countries       0
# seasons                 2199
# imdb_id                  159
# imdb_score               212
# imdb_votes               212
# tmdb_popularity           57
# tmdb_score               488
# dtype: int64

# %%
# 각 컬럼 간 상관관계
para_titles.corr()
# Out:
#                  release_year   runtime   seasons  imdb_score  imdb_votes  \
# release_year         1.000000 -0.148340 -0.473802    0.111226    0.058203
# runtime             -0.148340  1.000000  0.018069   -0.131106    0.290752
# seasons             -0.473802  0.018069  1.000000   -0.033239    0.166703
# imdb_score           0.111226 -0.131106 -0.033239    1.000000    0.224220
# imdb_votes           0.058203  0.290752  0.166703    0.224220    1.000000
# tmdb_popularity      0.074511 -0.007062  0.069984    0.063749    0.083950
# tmdb_score           0.219097 -0.215393 -0.027504    0.582808    0.189729
#
#                  tmdb_popularity  tmdb_score
# release_year            0.074511    0.219097
# runtime                -0.007062   -0.215393
# seasons                 0.069984   -0.027504
# imdb_score              0.063749    0.582808
# imdb_votes              0.083950    0.189729
# tmdb_popularity         1.000000    0.110097
# tmdb_score              0.110097    1.000000

# %%
fig = plt.figure(figsize=(8,8))
fig.set_facecolor('white')
 
sns.heatmap(para_titles.corr(), annot=True)
 
plt.show()

# %%
# 필요없는 컬럼 제거
para = para_titles.drop(['age_certification', 'production_countries', 'imdb_id', 'description'], axis=1)
para
# Out:
#              id                                             title   type  \
# 0       tm19248                                       The General  MOVIE
# 1       tm83884                                   His Girl Friday  MOVIE
# 2       tm19424                                            Detour  MOVIE
# 3      tm112005                                         Marihuana  MOVIE
# 4       tm22806  Intolerance: Love's Struggle Throughout the Ages  MOVIE
# ...         ...                                               ...    ...
# 2820   ts305329                         House Calls with Dr. Phil   SHOW
# 2821   ts291097          Disrupt & Dismantle with Soledad O'Brien   SHOW
# 2822  tm1100359               Race Against Time: The CIA and 9/11  MOVIE
# 2823  tm1097570                      Virus Hunting: Cave to COVID  MOVIE
# 2824  tm1032011                            Yukon's Wild Grizzlies  MOVIE
#
#       release_year  runtime  \
# 0             1926       78
# 1             1940       92
# 2             1945       66
# 3             1936       57
# 4             1916      197
# ...            ...      ...
# 2820          2021       43
# 2821          2021       40
# 2822          2021       89
# 2823          2021       60
# 2824          2021       44
#
#                                                  genres  seasons  imdb_score  \
# 0     ['action', 'drama', 'war', 'western', 'comedy'...      NaN         8.2
# 1                        ['comedy', 'drama', 'romance']      NaN         7.8
# 2                        ['thriller', 'drama', 'crime']      NaN         7.3
# 3                                    ['crime', 'drama']      NaN         4.0
# 4                                  ['history', 'drama']      NaN         7.7
# ...                                                 ...      ...         ...
# 2820                                        ['reality']      1.0         5.4
# 2821                                  ['documentation']      1.0         3.5
# 2822                                  ['documentation']      NaN         4.6
# 2823                                                 []      NaN         NaN
# 2824                                  ['documentation']      NaN         NaN
#
#       imdb_votes  tmdb_popularity  tmdb_score
# 0        89766.0            8.647         8.0
# 1        57835.0           11.270         7.4
# 2        17233.0            7.757         7.2
# 3          864.0            3.748         3.6
# 4        15242.0            9.412         7.2
# ...          ...              ...         ...
# 2820        35.0            0.600         NaN
# 2821        18.0              NaN         NaN
# 2822        64.0            2.403         NaN
# 2823         NaN            0.600         NaN
# 2824         NaN            0.600         7.0
#
# [2825 rows x 11 columns]

# %%
# seasons 컬럼은 결측치를 0으로 변경
para['seasons'] = para['seasons'].fillna(0)
print(para.shape)
para['seasons'].isnull().sum()
# Out:
# (2825, 11)
# 0

# %%
# imdb와 tmdb score가 둘 중 하나 NaN값인 경우 서로 채워주기
para['imdb_score'] = para['imdb_score'].fillna(para['tmdb_score'])

# %%
# imdb와 tmdb score가 둘 중 하나 NaN값인 경우 서로 채워주기
para['tmdb_score'] = para['tmdb_score'].fillna(para['imdb_score'])

# %%
# 보간 후 컬럼별 결측치 총합
para.isnull().sum()
# Out:
# id                   0
# title                0
# type                 0
# release_year         0
# runtime              0
# genres               0
# seasons              0
# imdb_score         132
# imdb_votes         212
# tmdb_popularity     57
# tmdb_score         132
# dtype: int64

# %%
# 몇 가지 컨텐츠를 직접 imdb와 tmdb에 넣어본 결과 대체로 진짜 점수가 없는 경우가 대다수였다.
# 인기있는 컨텐츠를 뽑을 때 score들이 없는 컨텐츠는 그만큼 인기가 없는 것이라 판단하고 결측치 제거
para = para.dropna(subset=['imdb_score', 'tmdb_score']).reset_index(drop=True)
print(para.shape)
para.isnull().sum()
# Out:
# (2693, 11)
# id                  0
# title               0
# type                0
# release_year        0
# runtime             0
# genres              0
# seasons             0
# imdb_score          0
# imdb_votes         80
# tmdb_popularity    34
# tmdb_score          0
# dtype: int64

# %%
para
# Out:
#              id                                             title   type  \
# 0       tm19248                                       The General  MOVIE
# 1       tm83884                                   His Girl Friday  MOVIE
# 2       tm19424                                            Detour  MOVIE
# 3      tm112005                                         Marihuana  MOVIE
# 4       tm22806  Intolerance: Love's Struggle Throughout the Ages  MOVIE
# ...         ...                                               ...    ...
# 2688  tm1106415       Destination Porto: The Unimaginable Journey  MOVIE
# 2689   ts305329                         House Calls with Dr. Phil   SHOW
# 2690   ts291097          Disrupt & Dismantle with Soledad O'Brien   SHOW
# 2691  tm1100359               Race Against Time: The CIA and 9/11  MOVIE
# 2692  tm1032011                            Yukon's Wild Grizzlies  MOVIE
#
#       release_year  runtime  \
# 0             1926       78
# 1             1940       92
# 2             1945       66
# 3             1936       57
# 4             1916      197
# ...            ...      ...
# 2688          2021       85
# 2689          2021       43
# 2690          2021       40
# 2691          2021       89
# 2692          2021       44
#
#                                                  genres  seasons  imdb_score  \
# 0     ['action', 'drama', 'war', 'western', 'comedy'...      0.0         8.2
# 1                        ['comedy', 'drama', 'romance']      0.0         7.8
# 2                        ['thriller', 'drama', 'crime']      0.0         7.3
# 3                                    ['crime', 'drama']      0.0         4.0
# 4                                  ['history', 'drama']      0.0         7.7
# ...                                                 ...      ...         ...
# 2688                                  ['documentation']      0.0         7.7
# 2689                                        ['reality']      1.0         5.4
# 2690                                  ['documentation']      1.0         3.5
# 2691                                  ['documentation']      0.0         4.6
# 2692                                  ['documentation']      0.0         7.0
#
#       imdb_votes  tmdb_popularity  tmdb_score
# 0        89766.0            8.647         8.0
# 1        57835.0           11.270         7.4
# 2        17233.0            7.757         7.2
# 3          864.0            3.748         3.6
# 4        15242.0            9.412         7.2
# ...          ...              ...         ...
# 2688         8.0            0.600         7.7
# 2689        35.0            0.600         5.4
# 2690        18.0              NaN         3.5
# 2691        64.0            2.403         4.6
# 2692         NaN            0.600         7.0
#
# [2693 rows x 11 columns]

# %%
# imdb score 상위 10개
top_imdbscore=para.sort_values('imdb_score',ascending=False)
top_imdbscore.head(10)
# Out:
#              id                         title   type  release_year  runtime  \
# 2588   ts217989      Rome's Chariot Superstar   SHOW          2019       44
# 2576   tm920735           My Father the Mover  MOVIE          2020       12
# 2687   tm994534              A Life Too Short  MOVIE          2021       35
# 2001   tm244637       China's Emperor Of Evil  MOVIE          2016       60
# 2422   ts223523  The Adventures of Paddington   SHOW          2019       16
# 2660  tm1175333            The Loyola Project  MOVIE          2022       88
# 2147   ts107506       Orangutan Jungle School   SHOW          2018       48
# 1244     ts3371    Avatar: The Last Airbender   SHOW          2005       24
# 547    tm155580                 The Godfather  MOVIE          1972      175
# 2359    ts77678          Love & Hip Hop Miami   SHOW          2018       42
#
#                                                  genres  seasons  imdb_score  \
# 2588                                  ['documentation']      1.0        10.0
# 2576                                  ['documentation']      0.0        10.0
# 2687                                  ['documentation']      0.0        10.0
# 2001                       ['documentation', 'history']      0.0        10.0
# 2422                                      ['animation']      2.0        10.0
# 2660                                  ['documentation']      0.0         9.4
# 2147                                  ['documentation']      2.0         9.4
# 1244  ['scifi', 'family', 'fantasy', 'animation', 'a...      3.0         9.3
# 547                                  ['drama', 'crime']      0.0         9.2
# 2359                                        ['reality']      4.0         9.1
#
#       imdb_votes  tmdb_popularity  tmdb_score
# 2588         NaN            0.931        10.0
# 2576         NaN            0.600        10.0
# 2687         NaN            0.840        10.0
# 2001         NaN            0.628        10.0
# 2422         NaN           13.250        10.0
# 2660        10.0            0.915         9.4
# 2147       143.0            1.272         8.5
# 1244    297336.0           61.284         8.7
# 547    1780564.0           61.778         8.7
# 2359         NaN            3.865         9.1

# %%
# 결측치 처리 전 imdb score 상위 10개
before_top_imdbscore=para_titles.sort_values('imdb_score',ascending=False)
before_top_imdbscore.head(10)
# Out:
#              id                       title   type  \
# 2775  tm1175333          The Loyola Project  MOVIE
# 2205   ts107506     Orangutan Jungle School   SHOW
# 1249     ts3371  Avatar: The Last Airbender   SHOW
# 549    tm155580               The Godfather  MOVIE
# 550     ts22109           The Twilight Zone   SHOW
# 552    tm112061      The Godfather: Part II  MOVIE
# 1741   ts166066            L.A. Frock Stars   SHOW
# 2080   ts125631           Ol Pejeta Diaries   SHOW
# 2151    ts53894       The New Edition Story   SHOW
# 2254   ts109900                      Rooted   SHOW
#
#                                             description  release_year  \
# 2775  In 1963, at the height of the civil rights mov...          2022
# 2205  Heartwarming stories from the largest animal r...          2018
# 1249  In a war-torn world of elemental magic, a youn...          2005
# 549   Spanning the years 1945 to 1955, a chronicle o...          1972
# 550   A series of unrelated stories containing drama...          1959
# 552   In the continuing saga of the Corleone crime f...          1974
# 1741  Series is a window into the world of high-end ...          2013
# 2080  Spanning 90,000 acres, the Ol Pejeta Conservan...          2015
# 2151  Follow the story of R&B pioneers Michael Bivin...          2017
# 2254  Rooted is the story of five iconic trees found...          2018
#
#      age_certification  runtime  \
# 2775               NaN       88
# 2205             TV-PG       48
# 1249             TV-Y7       24
# 549                  R      175
# 550              TV-PG       28
# 552                  R      195
# 1741             TV-PG       32
# 2080             TV-PG       23
# 2151             TV-14       77
# 2254             TV-PG       48
#
#                                                  genres production_countries  \
# 2775                                  ['documentation']                   []
# 2205                                  ['documentation']         ['AU', 'US']
# 1249  ['scifi', 'family', 'fantasy', 'animation', 'a...               ['US']
# 549                                  ['drama', 'crime']               ['US']
# 550   ['scifi', 'drama', 'fantasy', 'horror', 'thril...               ['US']
# 552                                  ['drama', 'crime']               ['US']
# 1741                                        ['reality']               ['ZA']
# 2080                                                 []                   []
# 2151                                 ['drama', 'music']               ['US']
# 2254                                  ['documentation']               ['ZA']
#
#       seasons     imdb_id  imdb_score  imdb_votes  tmdb_popularity  tmdb_score
# 2775      NaN  tt17886914         9.4        10.0            0.915         NaN
# 2205      2.0   tt8917574         9.4       143.0            1.272         8.5
# 1249      3.0   tt0417299         9.3    297336.0           61.284         8.7
# 549       NaN   tt0068646         9.2   1780564.0           61.778         8.7
# 550       5.0   tt0052520         9.1     80605.0           29.897         8.5
# 552       NaN   tt0071562         9.0   1230117.0           48.475         8.6
# 1741      2.0   tt2525446         9.0        41.0              NaN         NaN
# 2080      3.0   tt6416324         9.0         6.0              NaN         NaN
# 2151      1.0   tt6186100         8.9      2894.0            6.674         8.1
# 2254      1.0   tt8524448         8.9        39.0            1.471         NaN

# %%
fig = plt.figure(figsize=(10,5))

plt.subplot(1,2,1)
# imdb scores 상위 10개 그래프(수치 표시)
x = top_imdbscore.head(10)['title']
y = top_imdbscore.head(10)['imdb_score']
bar = plt.bar(x, y, color='gold', alpha=0.5)
plt.ylim(0, 12)

for rect in bar:
    height = rect.get_height()
    plt.text(rect.get_x() + rect.get_width()/2.0, height, '%.1f' % height, ha='center', va='bottom', size = 12)
    
plt.xticks(rotation=90)
plt.title("Top10 IMDB score in Paramount",fontweight="bold")

plt.subplot(1,2,2)
# 결측치 제거 전 imdb scores top 10(수치 표시)
x = before_top_imdbscore.head(10)['title']
y = before_top_imdbscore.head(10)['imdb_score']
bar = plt.bar(x, y, color='gold', alpha=0.5)
plt.ylim(0, 12)

for rect in bar:
    height = rect.get_height()
    plt.text(rect.get_x() + rect.get_width()/2.0, height, '%.1f' % height, ha='center', va='bottom', size = 12)
    
plt.xticks(rotation=90)
plt.title("Top10 IMDB score in Paramount Before Data Preprocessing",fontweight="bold")

plt.tight_layout()
plt.show()

# %%
# imdb votes 상위 10개
top_imdbvotes=para.sort_values('imdb_votes',ascending=False)
top_imdbvotes.head(10)
# Out:
#             id                   title   type  release_year  runtime  \
# 1072  tm122434            Forrest Gump  MOVIE          1994      142
# 1068  tm112130            Pulp Fiction  MOVIE          1994      154
# 547   tm155580           The Godfather  MOVIE          1972      175
# 1614  tm157099            Interstellar  MOVIE          2014      169
# 1509   tm41792        Django Unchained  MOVIE          2012      165
# 1073   tm28142               Gladiator  MOVIE          2000      155
# 1077   tm57554     Saving Private Ryan  MOVIE          1998      169
# 550   tm112061  The Godfather: Part II  MOVIE          1974      195
# 1069  tm191110                 Titanic  MOVIE          1997      194
# 1084  tm116655  Léon: The Professional  MOVIE          1994      110
#
#                                                  genres  seasons  imdb_score  \
# 1072                     ['romance', 'comedy', 'drama']      0.0         8.8
# 1068                     ['thriller', 'crime', 'drama']      0.0         8.9
# 547                                  ['drama', 'crime']      0.0         9.2
# 1614                     ['scifi', 'drama', 'thriller']      0.0         8.6
# 1509                               ['western', 'drama']      0.0         8.4
# 1073                                ['drama', 'action']      0.0         8.5
# 1077                                   ['drama', 'war']      0.0         8.6
# 550                                  ['drama', 'crime']      0.0         9.0
# 1069                               ['drama', 'romance']      0.0         7.9
# 1084  ['crime', 'thriller', 'action', 'drama', 'euro...      0.0         8.5
#
#       imdb_votes  tmdb_popularity  tmdb_score
# 1072   1994599.0           57.114         8.5
# 1068   1982722.0           55.923         8.5
# 547    1780564.0           61.778         8.7
# 1614   1728756.0          122.172         8.4
# 1509   1472668.0           56.588         8.1
# 1073   1453300.0           52.290         8.2
# 1077   1346020.0           54.874         8.2
# 550    1230117.0           48.475         8.6
# 1069   1133692.0          127.413         7.9
# 1084   1126151.0           41.872         8.3

# %%
# imdb votes top 10(수치 표시)
x = top_imdbvotes.head(10)['title']
y = top_imdbvotes.head(10)['imdb_votes']
bar = plt.bar(x, y, color='gold', alpha=0.5)

for rect in bar:
    height = rect.get_height()
    plt.text(rect.get_x() + rect.get_width()/2.0, height, '%.1f' % height, ha='center', va='bottom', size = 6)
    
plt.xticks(rotation=90)
plt.title("Top10 IMDB votes in Paramount",fontweight="bold")

plt.show()

# %%
fig = plt.figure(figsize=(10,7))

# 상위 10개의 IMDB votes에 해당하는 컨텐츠의 IMDB score
plt.subplot(1,2,1)
x = top_imdbvotes.head(10)['title']
y = top_imdbvotes.head(10)['imdb_score']
bar = plt.bar(x, y, color='gold', alpha=0.5)

for rect in bar:
    height = rect.get_height()
    plt.text(rect.get_x() + rect.get_width()/2.0, height, '%.1f' % height, ha='center', va='bottom', size = 6)
    
plt.xticks(rotation=90)
plt.title("IMDB score of Top10 IMDB votes in Paramount",fontweight="bold")

# 상위 10개의 IMDB votes에 해당하는 컨텐츠의 TMDB score
plt.subplot(1,2,2)
x = top_imdbvotes.head(10)['title']
y = top_imdbvotes.head(10)['tmdb_score']
bar = plt.bar(x, y, color='gold', alpha=0.5)

for rect in bar:
    height = rect.get_height()
    plt.text(rect.get_x() + rect.get_width()/2.0, height, '%.1f' % height, ha='center', va='bottom', size = 6)
    
plt.xticks(rotation=90)
plt.title("TMDB score of Top10 IMDB votes in Paramount",fontweight="bold")

plt.tight_layout()
plt.show()

# %%
# tmdb popularity 상위 10개
top_tmdbpopularity=para.sort_values('tmdb_popularity',ascending=False)
top_tmdbpopularity.head(10)
# Out:
#              id                            title   type  release_year  \
# 2597    ts43075                             Halo   SHOW          2022
# 2381   tm374139               Sonic the Hedgehog  MOVIE          2020
# 1116    ts15312  The Daily Show with Trevor Noah   SHOW          1996
# 2596  tm1000711                    The Lost City  MOVIE          2022
# 2604   tm927825                           Scream  MOVIE          2022
# 2608   tm460993         Clifford the Big Red Dog  MOVIE          2021
# 2600   tm847080                  Jackass Forever  MOVIE          2022
# 2621  tm1151009                   The In Between  MOVIE          2022
# 1618    ts20773                         Scorpion   SHOW          2014
# 2051   ts304703                         S.W.A.T.   SHOW          2017
#
#       runtime                                             genres  seasons  \
# 2597       52             ['scifi', 'thriller', 'war', 'action']      1.0
# 2381       99  ['scifi', 'action', 'comedy', 'family', 'fanta...      0.0
# 1116       32                                         ['comedy']     27.0
# 2596      112                    ['action', 'comedy', 'romance']      0.0
# 2604      114                             ['thriller', 'horror']      0.0
# 2608       97  ['fantasy', 'comedy', 'family', 'animation', '...      0.0
# 2600       96              ['comedy', 'action', 'documentation']      0.0
# 2621      116                      ['romance', 'drama', 'scifi']      0.0
# 1618       42           ['action', 'drama', 'thriller', 'crime']      4.0
# 2051       42           ['crime', 'drama', 'thriller', 'action']      6.0
#
#       imdb_score  imdb_votes  tmdb_popularity  tmdb_score
# 2597         7.1     31375.0         4579.160         8.7
# 2381         6.5    126887.0          893.650         7.4
# 1116         8.3     46718.0          749.525         6.4
# 2596         6.5     23688.0          707.594         6.8
# 2604         6.4     87810.0          559.107         6.8
# 2608         5.9     11522.0          482.744         7.3
# 2600         7.0     32699.0          468.032         6.9
# 2621         5.8      5755.0          446.897         7.1
# 1618         7.0     52547.0          443.639         8.3
# 2051         7.0     21813.0          439.647         8.1

# %%
# tmdb popularity top 10(수치 표시)
x = top_tmdbpopularity.head(10)['title']
y = top_tmdbpopularity.head(10)['tmdb_popularity']
bar = plt.bar(x, y, color='gold', alpha=0.5)

for rect in bar:
    height = rect.get_height()
    plt.text(rect.get_x() + rect.get_width()/2.0, height, '%.1f' % height, ha='center', va='bottom', size = 6)
    
plt.xticks(rotation=90)
plt.title("Top10 TMDB popularity in Paramount",fontweight="bold")

plt.show()

# %%
fig = plt.figure(figsize=(10,5))

# 상위 10개의 TMDB popularity에 해당하는 컨텐츠의 IMDB score
plt.subplot(1,2,1)
x = top_imdbvotes.head(10)['title']
y = top_imdbvotes.head(10)['imdb_score']
bar = plt.bar(x, y, color='gold', alpha=0.5)

for rect in bar:
    height = rect.get_height()
    plt.text(rect.get_x() + rect.get_width()/2.0, height, '%.1f' % height, ha='center', va='bottom', size = 6)
    
plt.xticks(rotation=90)
plt.title("IMDB score of Top10 IMDB popularity in Paramount",fontweight="bold")

# 상위 10개의 TMDB popularity에 해당하는 컨텐츠의 TMDB score
plt.subplot(1,2,2)
x = top_imdbvotes.head(10)['title']
y = top_imdbvotes.head(10)['tmdb_score']
bar = plt.bar(x, y, color='Gold', alpha=0.5)

for rect in bar:
    height = rect.get_height()
    plt.text(rect.get_x() + rect.get_width()/2.0, height, '%.1f' % height, ha='center', va='bottom', size = 6)
    
plt.xticks(rotation=90)
plt.title("TMDB score of Top10 TMDB popularity in Paramount",fontweight="bold")

plt.tight_layout()
plt.show()

# %%
# tmdb score 상위 10개
top_tmdbscore=para.sort_values('tmdb_score',ascending=False)
top_tmdbscore.head(10)
# Out:
#             id                                              title   type  \
# 2001  tm244637                            China's Emperor Of Evil  MOVIE
# 2103   ts76985                                     The Lost Tapes   SHOW
# 1410   ts18694                                    The Buried Life   SHOW
# 2284   ts58087                     Hood Adjacent with James Davis   SHOW
# 1023   tm53190                              Predator: The Quietus  MOVIE
# 2353  tm307673                The Obama Years: The Power of Words  MOVIE
# 1482   tm79411  Christopher Titus: The 5th Annual End of the W...  MOVIE
# 1989  tm405222                             Behind Some Dark Cloud  MOVIE
# 2591  ts216123                                    Love & Listings   SHOW
# 2440  tm880110                                    Woman in Motion  MOVIE
#
#       release_year  runtime  \
# 2001          2016       60
# 2103          2017       58
# 1410          2010       22
# 2284          2017       21
# 1023          1988       90
# 2353          2017       51
# 1482          2007       60
# 1989          2015       90
# 2591          2019       42
# 2440          2019       96
#
#                                                  genres  seasons  imdb_score  \
# 2001                       ['documentation', 'history']      0.0        10.0
# 2103  ['documentation', 'drama', 'history', 'music',...      1.0         8.6
# 1410             ['comedy', 'reality', 'documentation']      2.0         8.6
# 2284                                         ['comedy']      1.0         5.6
# 1023                                         ['horror']      0.0         3.0
# 2353                                  ['documentation']      0.0         7.0
# 1482                        ['comedy', 'documentation']      0.0         7.9
# 1989                               ['drama', 'romance']      0.0         5.9
# 2591                                        ['reality']      2.0         6.0
# 2440                                  ['documentation']      0.0         8.5
#
#       imdb_votes  tmdb_popularity  tmdb_score
# 2001         NaN            0.628        10.0
# 2103         9.0            0.600        10.0
# 1410       597.0            1.941        10.0
# 2284       151.0            0.708        10.0
# 1023       132.0            0.961        10.0
# 2353         5.0            0.600        10.0
# 1482       173.0            1.211        10.0
# 1989        21.0            0.600        10.0
# 2591       405.0            0.983        10.0
# 2440       297.0            2.056        10.0

# %%
# 결측치 처리 전 tmdb votes 상위 10개
before_top_tmdbscore=para.sort_values('tmdb_score',ascending=False)
before_top_tmdbscore.head(10)
# Out:
#             id                                              title   type  \
# 2001  tm244637                            China's Emperor Of Evil  MOVIE
# 2103   ts76985                                     The Lost Tapes   SHOW
# 1410   ts18694                                    The Buried Life   SHOW
# 2284   ts58087                     Hood Adjacent with James Davis   SHOW
# 1023   tm53190                              Predator: The Quietus  MOVIE
# 2353  tm307673                The Obama Years: The Power of Words  MOVIE
# 1482   tm79411  Christopher Titus: The 5th Annual End of the W...  MOVIE
# 1989  tm405222                             Behind Some Dark Cloud  MOVIE
# 2591  ts216123                                    Love & Listings   SHOW
# 2440  tm880110                                    Woman in Motion  MOVIE
#
#       release_year  runtime  \
# 2001          2016       60
# 2103          2017       58
# 1410          2010       22
# 2284          2017       21
# 1023          1988       90
# 2353          2017       51
# 1482          2007       60
# 1989          2015       90
# 2591          2019       42
# 2440          2019       96
#
#                                                  genres  seasons  imdb_score  \
# 2001                       ['documentation', 'history']      0.0        10.0
# 2103  ['documentation', 'drama', 'history', 'music',...      1.0         8.6
# 1410             ['comedy', 'reality', 'documentation']      2.0         8.6
# 2284                                         ['comedy']      1.0         5.6
# 1023                                         ['horror']      0.0         3.0
# 2353                                  ['documentation']      0.0         7.0
# 1482                        ['comedy', 'documentation']      0.0         7.9
# 1989                               ['drama', 'romance']      0.0         5.9
# 2591                                        ['reality']      2.0         6.0
# 2440                                  ['documentation']      0.0         8.5
#
#       imdb_votes  tmdb_popularity  tmdb_score
# 2001         NaN            0.628        10.0
# 2103         9.0            0.600        10.0
# 1410       597.0            1.941        10.0
# 2284       151.0            0.708        10.0
# 1023       132.0            0.961        10.0
# 2353         5.0            0.600        10.0
# 1482       173.0            1.211        10.0
# 1989        21.0            0.600        10.0
# 2591       405.0            0.983        10.0
# 2440       297.0            2.056        10.0

# %%
fig = plt.figure(figsize=(10,7))

plt.subplot(1,2,1)
# tmdb scores top 10(수치 표시)
x = top_tmdbscore.head(10)['title']
y = top_tmdbscore.head(10)['tmdb_score']
bar = plt.bar(x, y, color='gold', alpha=0.5)
plt.ylim(0, 12)

for rect in bar:
    height = rect.get_height()
    plt.text(rect.get_x() + rect.get_width()/2.0, height, '%.1f' % height, ha='center', va='bottom', size = 12)
    
plt.xticks(rotation=90)
plt.title("Top10 TMDB score in Paramount",fontweight="bold")



plt.subplot(1,2,2)
# tmdb scores top 10(수치 표시)
x = before_top_tmdbscore.head(10)['title']
y = before_top_tmdbscore.head(10)['tmdb_score']
bar = plt.bar(x, y, color='gold', alpha=0.5)
plt.ylim(0, 12)

for rect in bar:
    height = rect.get_height()
    plt.text(rect.get_x() + rect.get_width()/2.0, height, '%.1f' % height, ha='center', va='bottom', size = 12)
    
plt.xticks(rotation=90)
plt.title("Top10 TMDB score in Paramount Before Data Preprocessing",fontweight="bold")

plt.tight_layout()
plt.show()
