# %% [markdown]
# # Disney+

# %%
# Pandas, Numpy, Matplotlib, Seaborn을 호출
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('default')
import seaborn as sns

# disney2 변수를 만들고 credits.csv 파일의 데이터를 할당
disney2 = pd.read_csv('~/aiffel/disney+/credits.csv')

# disney2의 head 값 확인하기
disney2.head()
# Out:
#    person_id       id               name  \
# 0      23433  tm74391       Deems Taylor
# 1       5910  tm74391        Walt Disney
# 2      23436  tm74391     Julietta Novis
# 3      23434  tm74391  Leopold Stokowski
# 4      23441  tm74391   Paul Satterfield
#
#                                            character      role
# 0                 Narrator - Narrative Introductions     ACTOR
# 1  Mickey Mouse (segment 'The Sorcerer's Apprenti...     ACTOR
# 2      Soloist (segment 'Ave Maria') (singing voice)     ACTOR
# 3  Himself - Conductor of The Philadelphia Orchestra     ACTOR
# 4                                                NaN  DIRECTOR

# %%
# disney1 변수를 만들고 titles.csv 파일의 데이터를 할당
disney1 = pd.read_csv('~/aiffel/disney+/titles.csv')

# disney1의 head 값 확인하기
disney1.head()
# Out:
#         id                            title   type  \
# 0  tm74391                         Fantasia  MOVIE
# 1  tm67803  Snow White and the Seven Dwarfs  MOVIE
# 2  tm82546                        Pinocchio  MOVIE
# 3  tm79357                            Bambi  MOVIE
# 4  tm62671                  Treasure Island  MOVIE
#
#                                          description  release_year  \
# 0  Walt Disney's timeless masterpiece is an extra...          1940
# 1  A beautiful girl, Snow White, takes refuge in ...          1937
# 2  Lonely toymaker Geppetto has his wishes answer...          1940
# 3  Bambi's tale unfolds from season to season as ...          1942
# 4  Enchanted by the idea of locating treasure bur...          1950
#
#   age_certification  runtime  \
# 0                 G      120
# 1                 G       83
# 2                 G       88
# 3                 G       70
# 4                PG       96
#
#                                               genres production_countries  \
# 0        ['animation', 'family', 'music', 'fantasy']               ['US']
# 1  ['fantasy', 'family', 'romance', 'animation', ...               ['US']
# 2       ['animation', 'comedy', 'family', 'fantasy']               ['US']
# 3                   ['animation', 'drama', 'family']               ['US']
# 4                               ['family', 'action']         ['GB', 'US']
#
#    seasons    imdb_id  imdb_score  imdb_votes  tmdb_popularity  tmdb_score
# 0      NaN  tt0032455         7.7     94681.0           57.751         7.4
# 1      NaN  tt0029583         7.6    195321.0          107.137         7.1
# 2      NaN  tt0032910         7.5    141937.0           71.160         7.1
# 3      NaN  tt0034492         7.3    140406.0           68.136         7.0
# 4      NaN  tt0043067         6.9      8229.0           10.698         6.5

# %%
# disney1의 정보 확인하기
disney1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1535 entries, 0 to 1534
# Data columns (total 15 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    1535 non-null   object
#  1   title                 1535 non-null   object
#  2   type                  1535 non-null   object
#  3   description           1529 non-null   object
#  4   release_year          1535 non-null   int64
#  5   age_certification     1210 non-null   object
#  6   runtime               1535 non-null   int64
#  7   genres                1535 non-null   object
#  8   production_countries  1535 non-null   object
#  9   seasons               415 non-null    float64
#  10  imdb_id               1133 non-null   object
#  11  imdb_score            1108 non-null   float64
#  12  imdb_votes            1105 non-null   float64
#  13  tmdb_popularity       1524 non-null   float64
#  14  tmdb_score            1426 non-null   float64
# dtypes: float64(5), int64(2), object(8)
# memory usage: 180.0+ KB

# %%
disney1.shape
# Out:
# (1535, 15)

# %%
# 결측치 확인
disney1.isnull().sum()
# Out:
# id                         0
# title                      0
# type                       0
# description                6
# release_year               0
# age_certification        325
# runtime                    0
# genres                     0
# production_countries       0
# seasons                 1120
# imdb_id                  402
# imdb_score               427
# imdb_votes               430
# tmdb_popularity           11
# tmdb_score               109
# dtype: int64

# %%
# 중복된 데이터 확인
disney1.duplicated().sum()
# Out:
# 0

# %%
# description 결측치 있는 행 제거
disney = disney1.dropna(subset=['description']).reset_index(drop=True)
print(disney.shape)
disney.isnull().sum()
# Out:
# (1529, 15)
# id                         0
# title                      0
# type                       0
# description                0
# release_year               0
# age_certification        320
# runtime                    0
# genres                     0
# production_countries       0
# seasons                 1118
# imdb_id                  400
# imdb_score               424
# imdb_votes               427
# tmdb_popularity            6
# tmdb_score               103
# dtype: int64

# %%
# 각 컬럼 간 상관관계
disney1.corr()
# Out:
#                  release_year   runtime   seasons  imdb_score  imdb_votes  \
# release_year         1.000000  0.035408 -0.323331    0.020416   -0.008797
# runtime              0.035408  1.000000  0.053115   -0.052458    0.431629
# seasons             -0.323331  0.053115  1.000000    0.109505    0.220509
# imdb_score           0.020416 -0.052458  0.109505    1.000000    0.293552
# imdb_votes          -0.008797  0.431629  0.220509    0.293552    1.000000
# tmdb_popularity      0.063519  0.071872  0.005160    0.067618    0.149533
# tmdb_score           0.219422 -0.189938 -0.053576    0.555856    0.124163
#
#                  tmdb_popularity  tmdb_score
# release_year            0.063519    0.219422
# runtime                 0.071872   -0.189938
# seasons                 0.005160   -0.053576
# imdb_score              0.067618    0.555856
# imdb_votes              0.149533    0.124163
# tmdb_popularity         1.000000    0.081074
# tmdb_score              0.081074    1.000000

# %% [markdown]
# #### 상관관계 분석
# relaese_year : tmdb_score
# runtime : imdb_votes
# seasons : imdb
# imdb_score : imdb_votes, tmdb_score
# imdb_votes : relaese_year빼고

# %%
fig = plt.figure(figsize=(8,8))
fig.set_facecolor('white')
 
sns.heatmap(disney1.corr(), annot=True)
 
plt.show()

# %%
disney1['seasons'].unique()
# Out:
# array([nan,  5.,  7.,  3.,  1., 34., 32.,  4.,  6.,  2.,  8.,  9., 11.,
#        20., 18., 10.])

# %%
ax=sns.barplot(x='type', y='seasons', data=disney1)

# %%
# seasons 컬럼은 결측치를 0으로 변경
disney['seasons'] = disney['seasons'].fillna(0)
print(disney.shape)
disney['seasons'].isnull().sum()
# Out:
# (1529, 15)
# 0

# %%
# 컬럼 제거
disney_data = disney.drop(['age_certification', 'production_countries', 'runtime', 'imdb_id', 'description'], axis=1)
disney_data
# Out:
#              id                            title   type  release_year  \
# 0       tm74391                         Fantasia  MOVIE          1940
# 1       tm67803  Snow White and the Seven Dwarfs  MOVIE          1937
# 2       tm82546                        Pinocchio  MOVIE          1940
# 3       tm79357                            Bambi  MOVIE          1942
# 4       tm62671                  Treasure Island  MOVIE          1950
# ...         ...                              ...    ...           ...
# 1524  tm1071287    Killer Shark vs. Killer Whale  MOVIE          2021
# 1525  tm1091101            Far From Raven's Home  MOVIE          2021
# 1526  tm1075680    World's Most Dangerous Shark?  MOVIE          2021
# 1527  tm1133820                  The Magic Maker  MOVIE          2021
# 1528  tm1091117      Smoky Mountain Park Rangers  MOVIE          2021
#
#                                                  genres  seasons  imdb_score  \
# 0           ['animation', 'family', 'music', 'fantasy']      0.0         7.7
# 1     ['fantasy', 'family', 'romance', 'animation', ...      0.0         7.6
# 2          ['animation', 'comedy', 'family', 'fantasy']      0.0         7.5
# 3                      ['animation', 'drama', 'family']      0.0         7.3
# 4                                  ['family', 'action']      0.0         6.9
# ...                                                 ...      ...         ...
# 1524                                  ['documentation']      0.0         6.4
# 1525                            ['animation', 'comedy']      0.0         5.6
# 1526                                  ['documentation']      0.0         NaN
# 1527                                                 []      0.0         4.2
# 1528                                  ['documentation']      0.0         NaN
#
#       imdb_votes  tmdb_popularity  tmdb_score
# 0        94681.0           57.751         7.4
# 1       195321.0          107.137         7.1
# 2       141937.0           71.160         7.1
# 3       140406.0           68.136         7.0
# 4         8229.0           10.698         6.5
# ...          ...              ...         ...
# 1524        17.0            1.061         4.0
# 1525         8.0            0.744        10.0
# 1526         NaN            1.400         NaN
# 1527         9.0            1.504         NaN
# 1528         NaN            1.761         NaN
#
# [1529 rows x 10 columns]

# %%
# 컬럼별 결측치 총합
disney_data.isnull().sum()
# Out:
# id                   0
# title                0
# type                 0
# release_year         0
# genres               0
# seasons              0
# imdb_score         424
# imdb_votes         427
# tmdb_popularity      6
# tmdb_score         103
# dtype: int64

# %%
# imdb와 tmdb score가 둘 중 하나 NaN값인 경우 서로 채워주기
disney_data['imdb_score'] = disney_data['imdb_score'].fillna(disney_data['tmdb_score'])
disney_data[(disney_data['imdb_score'].isnull())]
# Out:
#              id                                              title   type  \
# 186    tm895685                  The Story of the Animated Drawing  MOVIE
# 188    tm918170             The Pre-Opening Report from Disneyland  MOVIE
# 196     tm94576                           Sultan And The Rock Star  MOVIE
# 803    tm895746                         America's Greatest Animals  MOVIE
# 902    tm940509                The Incredible Dr. Pol: Jingle Pols  MOVIE
# 1003   ts123278                                  First Class Chefs   SHOW
# 1004   ts269031                                      Party Animals   SHOW
# 1005    ts80444                                   Nature Boom Time   SHOW
# 1008   tm833134                              World's Greatest Dogs  MOVIE
# 1010   tm937148            The Incredible Dr. Pol Blue Ribbon Kids  MOVIE
# 1011   tm921369                                      Big Cat Games  MOVIE
# 1012   ts237993                       The Book of Once Upon a Time   SHOW
# 1084   ts237940                     Avengers: Secret Wars (Shorts)   SHOW
# 1093   ts251053                                    Animal Showdown   SHOW
# 1104   ts254161                                  Scuba Sam's World   SHOW
# 1110  tm1018769  Disney Illuminations Firework Show Disneyland ...  MOVIE
# 1118   ts254582                                      Best Job Ever   SHOW
# 1122   ts237134                                        Love & Vets   SHOW
# 1123   ts254331                          Weirdest, Bestest, Truest   SHOW
# 1124   ts251368                                  Destination World   SHOW
# 1127    ts80441                                    Awesome Animals   SHOW
# 1129   ts254154                          Sam's Zookeeper Challenge   SHOW
# 1130   ts251352              Fearless Adventures with Jack Randall   SHOW
# 1132   tm987733                                    Big Sharks Rule  MOVIE
# 1133   tm983642                                        Wild Uganda  MOVIE
# 1134   tm362746        Disney’s Fairy Tale Weddings: Holiday Magic  MOVIE
# 1135    ts80440                                      What Sam Sees   SHOW
# 1164  tm1115985                          Buried Secrets of Cordoba  MOVIE
# 1172  tm1142436                            Buried Secrets of Keros  MOVIE
# 1202   ts249303                                         Spaced Out   SHOW
# 1235   ts254535                               Wild Central America   SHOW
# 1253   ts222776                           Marvel's Ultimate Comics   SHOW
# 1270   tm924794                              India's Wild Leopards  MOVIE
# 1293   ts277494                  Disney Junior Ready for Preschool   SHOW
# 1301   tm920883                                          Sharkcano  MOVIE
# 1307   tm975596                              Ultimate Viking Sword  MOVIE
# 1309   ts320472                                     Broken Karaoke   SHOW
# 1312   tm983746                              Great Shark Chow Down  MOVIE
# 1319   tm981436                      Doc McStuffins: The Doc Is In  MOVIE
# 1320  tm1064056  Shark Attack Investigation: The Paige Winter S...  MOVIE
# 1332   tm916470         The Undefeated Presents: Hamilton In-Depth  MOVIE
# 1333   ts271622                                       Roll it Back   SHOW
# 1345  tm1030667                                    What the Shark?  MOVIE
# 1347  tm1075291                                 Most Wanted Sharks  MOVIE
# 1349   tm983647                                  Texas Storm Squad  MOVIE
# 1353   tm995604                                  Jade Eyed Leopard  MOVIE
# 1390   ts342882                                         Sketchbook   SHOW
# 1433  tm1184089  Step Into… The Movies with Derek and Julianne ...  MOVIE
# 1440   ts272834     America's Funniest Home Videos: Animal Edition   SHOW
# 1453   ts320493                                 Called to the Wild   SHOW
# 1480   ts285348                         Kingdom of the Polar Bears   SHOW
# 1482   ts342942                                         Eye Wonder   SHOW
# 1489  tm1110156                       Lost Cities: The Great Flood  MOVIE
# 1494  tm1160996                             The Way of the Cheetah  MOVIE
# 1510   ts272675                               Breaking Bobby Bones   SHOW
# 1519   ts313961                                  Vets on the Beach   SHOW
# 1526  tm1075680                      World's Most Dangerous Shark?  MOVIE
# 1528  tm1091117                        Smoky Mountain Park Rangers  MOVIE
#
#       release_year                                  genres  seasons  \
# 186           1955                       ['documentation']      0.0
# 188           1955  ['family', 'documentation', 'history']      0.0
# 196           1980                               ['drama']      0.0
# 803           2012                       ['documentation']      0.0
# 902           2013                       ['documentation']      0.0
# 1003          2015                   ['family', 'reality']      1.0
# 1004          2016                       ['documentation']      1.0
# 1005          2016                                      []      1.0
# 1008          2015                                      []      0.0
# 1010          2016                       ['documentation']      0.0
# 1011          2015             ['documentation', 'family']      0.0
# 1012          2015                                      []      4.0
# 1084          2017                                      []      1.0
# 1093          2018             ['documentation', 'family']      1.0
# 1104          2018                                      []      1.0
# 1110          2017                               ['music']      0.0
# 1118          2018                       ['documentation']      1.0
# 1122          2017                       ['documentation']      1.0
# 1123          2018                                      []      1.0
# 1124          2018                       ['documentation']      1.0
# 1127          2017                                      []      1.0
# 1129          2018                                      []      1.0
# 1130          2018                                      []      1.0
# 1132          2018                       ['documentation']      0.0
# 1133          2018                       ['documentation']      0.0
# 1134          2017              ['drama', 'documentation']      0.0
# 1135          2018                                      []      1.0
# 1164          2019            ['history', 'documentation']      0.0
# 1172          2020                       ['documentation']      0.0
# 1202          2019                               ['scifi']      1.0
# 1235          2020                       ['documentation']      1.0
# 1253          2019                                      []      1.0
# 1270          2020                       ['documentation']      0.0
# 1293          2019                              ['family']      2.0
# 1301          2020                       ['documentation']      0.0
# 1307          2019            ['history', 'documentation']      0.0
# 1309          2019                 ['comedy', 'animation']      1.0
# 1312          2019                       ['documentation']      0.0
# 1319          2020                           ['animation']      0.0
# 1320          2020                       ['documentation']      0.0
# 1332          2020                                      []      0.0
# 1333          2019                       ['documentation']      1.0
# 1345          2020                       ['documentation']      0.0
# 1347          2020                                      []      0.0
# 1349          2020                       ['documentation']      0.0
# 1353          2020                       ['documentation']      0.0
# 1390          2022                       ['documentation']      1.0
# 1433          2022                                      []      0.0
# 1440          2021                   ['family', 'reality']      1.0
# 1453          2021                             ['reality']      1.0
# 1480          2021                       ['documentation']      1.0
# 1482          2021                             ['reality']      1.0
# 1489          2021                       ['documentation']      0.0
# 1494          2022                       ['documentation']      0.0
# 1510          2021                       ['documentation']      1.0
# 1519          2021                       ['documentation']      1.0
# 1526          2021                       ['documentation']      0.0
# 1528          2021                       ['documentation']      0.0
#
#       imdb_score  imdb_votes  tmdb_popularity  tmdb_score
# 186          NaN         NaN            1.543         NaN
# 188          NaN         NaN            0.854         NaN
# 196          NaN         NaN            1.516         NaN
# 803          NaN         NaN            3.534         NaN
# 902          NaN         NaN            0.600         NaN
# 1003         NaN         NaN            0.600         NaN
# 1004         NaN         NaN            0.600         NaN
# 1005         NaN         NaN            2.405         NaN
# 1008         NaN         NaN            0.885         NaN
# 1010         NaN         NaN            0.600         NaN
# 1011         NaN         NaN            1.513         NaN
# 1012         NaN         NaN            0.606         NaN
# 1084         NaN         NaN            0.603         NaN
# 1093         NaN         NaN            0.600         NaN
# 1104         NaN         NaN            0.600         NaN
# 1110         NaN         NaN            1.268         NaN
# 1118         NaN         NaN            0.604         NaN
# 1122         NaN         NaN            0.600         NaN
# 1123         NaN         NaN            0.857         NaN
# 1124         NaN         NaN            0.600         NaN
# 1127         NaN         NaN            1.720         NaN
# 1129         NaN         NaN            0.600         NaN
# 1130         NaN         NaN            0.600         NaN
# 1132         NaN         NaN            1.217         NaN
# 1133         NaN         NaN            0.930         NaN
# 1134         NaN         NaN            0.600         NaN
# 1135         NaN         NaN            3.225         NaN
# 1164         NaN         NaN            1.358         NaN
# 1172         NaN         NaN            0.875         NaN
# 1202         NaN         NaN            0.600         NaN
# 1235         NaN         NaN            1.828         NaN
# 1253         NaN         NaN            3.842         NaN
# 1270         NaN         NaN            0.874         NaN
# 1293         NaN         NaN            1.245         NaN
# 1301         NaN         NaN            1.408         NaN
# 1307         NaN         NaN            1.981         NaN
# 1309         NaN         NaN            1.094         NaN
# 1312         NaN         NaN            1.532         NaN
# 1319         NaN         NaN            0.637         NaN
# 1320         NaN         NaN            1.464         NaN
# 1332         NaN         NaN            2.744         NaN
# 1333         NaN         NaN            0.600         NaN
# 1345         NaN         NaN            1.461         NaN
# 1347         NaN         NaN            0.959         NaN
# 1349         NaN         NaN            1.219         NaN
# 1353         NaN         NaN            2.463         NaN
# 1390         NaN         NaN            7.350         NaN
# 1433         NaN         NaN            1.562         NaN
# 1440         NaN         NaN            1.400         NaN
# 1453         NaN         NaN            0.600         NaN
# 1480         NaN         NaN            1.183         NaN
# 1482         NaN         NaN            0.764         NaN
# 1489         NaN         NaN            1.525         NaN
# 1494         NaN         NaN            1.976         NaN
# 1510         NaN         NaN            1.400         NaN
# 1519         NaN         NaN            1.960         NaN
# 1526         NaN         NaN            1.400         NaN
# 1528         NaN         NaN            1.761         NaN

# %%
# imdb와 tmdb score가 둘 중 하나 NaN값인 경우 서로 채워주기
disney_data['tmdb_score'] = disney_data['tmdb_score'].fillna(disney_data['imdb_score'])
disney_data[(disney_data['tmdb_score'].isnull())]
# Out:
#              id                                              title   type  \
# 186    tm895685                  The Story of the Animated Drawing  MOVIE
# 188    tm918170             The Pre-Opening Report from Disneyland  MOVIE
# 196     tm94576                           Sultan And The Rock Star  MOVIE
# 803    tm895746                         America's Greatest Animals  MOVIE
# 902    tm940509                The Incredible Dr. Pol: Jingle Pols  MOVIE
# 1003   ts123278                                  First Class Chefs   SHOW
# 1004   ts269031                                      Party Animals   SHOW
# 1005    ts80444                                   Nature Boom Time   SHOW
# 1008   tm833134                              World's Greatest Dogs  MOVIE
# 1010   tm937148            The Incredible Dr. Pol Blue Ribbon Kids  MOVIE
# 1011   tm921369                                      Big Cat Games  MOVIE
# 1012   ts237993                       The Book of Once Upon a Time   SHOW
# 1084   ts237940                     Avengers: Secret Wars (Shorts)   SHOW
# 1093   ts251053                                    Animal Showdown   SHOW
# 1104   ts254161                                  Scuba Sam's World   SHOW
# 1110  tm1018769  Disney Illuminations Firework Show Disneyland ...  MOVIE
# 1118   ts254582                                      Best Job Ever   SHOW
# 1122   ts237134                                        Love & Vets   SHOW
# 1123   ts254331                          Weirdest, Bestest, Truest   SHOW
# 1124   ts251368                                  Destination World   SHOW
# 1127    ts80441                                    Awesome Animals   SHOW
# 1129   ts254154                          Sam's Zookeeper Challenge   SHOW
# 1130   ts251352              Fearless Adventures with Jack Randall   SHOW
# 1132   tm987733                                    Big Sharks Rule  MOVIE
# 1133   tm983642                                        Wild Uganda  MOVIE
# 1134   tm362746        Disney’s Fairy Tale Weddings: Holiday Magic  MOVIE
# 1135    ts80440                                      What Sam Sees   SHOW
# 1164  tm1115985                          Buried Secrets of Cordoba  MOVIE
# 1172  tm1142436                            Buried Secrets of Keros  MOVIE
# 1202   ts249303                                         Spaced Out   SHOW
# 1235   ts254535                               Wild Central America   SHOW
# 1253   ts222776                           Marvel's Ultimate Comics   SHOW
# 1270   tm924794                              India's Wild Leopards  MOVIE
# 1293   ts277494                  Disney Junior Ready for Preschool   SHOW
# 1301   tm920883                                          Sharkcano  MOVIE
# 1307   tm975596                              Ultimate Viking Sword  MOVIE
# 1309   ts320472                                     Broken Karaoke   SHOW
# 1312   tm983746                              Great Shark Chow Down  MOVIE
# 1319   tm981436                      Doc McStuffins: The Doc Is In  MOVIE
# 1320  tm1064056  Shark Attack Investigation: The Paige Winter S...  MOVIE
# 1332   tm916470         The Undefeated Presents: Hamilton In-Depth  MOVIE
# 1333   ts271622                                       Roll it Back   SHOW
# 1345  tm1030667                                    What the Shark?  MOVIE
# 1347  tm1075291                                 Most Wanted Sharks  MOVIE
# 1349   tm983647                                  Texas Storm Squad  MOVIE
# 1353   tm995604                                  Jade Eyed Leopard  MOVIE
# 1390   ts342882                                         Sketchbook   SHOW
# 1433  tm1184089  Step Into… The Movies with Derek and Julianne ...  MOVIE
# 1440   ts272834     America's Funniest Home Videos: Animal Edition   SHOW
# 1453   ts320493                                 Called to the Wild   SHOW
# 1480   ts285348                         Kingdom of the Polar Bears   SHOW
# 1482   ts342942                                         Eye Wonder   SHOW
# 1489  tm1110156                       Lost Cities: The Great Flood  MOVIE
# 1494  tm1160996                             The Way of the Cheetah  MOVIE
# 1510   ts272675                               Breaking Bobby Bones   SHOW
# 1519   ts313961                                  Vets on the Beach   SHOW
# 1526  tm1075680                      World's Most Dangerous Shark?  MOVIE
# 1528  tm1091117                        Smoky Mountain Park Rangers  MOVIE
#
#       release_year                                  genres  seasons  \
# 186           1955                       ['documentation']      0.0
# 188           1955  ['family', 'documentation', 'history']      0.0
# 196           1980                               ['drama']      0.0
# 803           2012                       ['documentation']      0.0
# 902           2013                       ['documentation']      0.0
# 1003          2015                   ['family', 'reality']      1.0
# 1004          2016                       ['documentation']      1.0
# 1005          2016                                      []      1.0
# 1008          2015                                      []      0.0
# 1010          2016                       ['documentation']      0.0
# 1011          2015             ['documentation', 'family']      0.0
# 1012          2015                                      []      4.0
# 1084          2017                                      []      1.0
# 1093          2018             ['documentation', 'family']      1.0
# 1104          2018                                      []      1.0
# 1110          2017                               ['music']      0.0
# 1118          2018                       ['documentation']      1.0
# 1122          2017                       ['documentation']      1.0
# 1123          2018                                      []      1.0
# 1124          2018                       ['documentation']      1.0
# 1127          2017                                      []      1.0
# 1129          2018                                      []      1.0
# 1130          2018                                      []      1.0
# 1132          2018                       ['documentation']      0.0
# 1133          2018                       ['documentation']      0.0
# 1134          2017              ['drama', 'documentation']      0.0
# 1135          2018                                      []      1.0
# 1164          2019            ['history', 'documentation']      0.0
# 1172          2020                       ['documentation']      0.0
# 1202          2019                               ['scifi']      1.0
# 1235          2020                       ['documentation']      1.0
# 1253          2019                                      []      1.0
# 1270          2020                       ['documentation']      0.0
# 1293          2019                              ['family']      2.0
# 1301          2020                       ['documentation']      0.0
# 1307          2019            ['history', 'documentation']      0.0
# 1309          2019                 ['comedy', 'animation']      1.0
# 1312          2019                       ['documentation']      0.0
# 1319          2020                           ['animation']      0.0
# 1320          2020                       ['documentation']      0.0
# 1332          2020                                      []      0.0
# 1333          2019                       ['documentation']      1.0
# 1345          2020                       ['documentation']      0.0
# 1347          2020                                      []      0.0
# 1349          2020                       ['documentation']      0.0
# 1353          2020                       ['documentation']      0.0
# 1390          2022                       ['documentation']      1.0
# 1433          2022                                      []      0.0
# 1440          2021                   ['family', 'reality']      1.0
# 1453          2021                             ['reality']      1.0
# 1480          2021                       ['documentation']      1.0
# 1482          2021                             ['reality']      1.0
# 1489          2021                       ['documentation']      0.0
# 1494          2022                       ['documentation']      0.0
# 1510          2021                       ['documentation']      1.0
# 1519          2021                       ['documentation']      1.0
# 1526          2021                       ['documentation']      0.0
# 1528          2021                       ['documentation']      0.0
#
#       imdb_score  imdb_votes  tmdb_popularity  tmdb_score
# 186          NaN         NaN            1.543         NaN
# 188          NaN         NaN            0.854         NaN
# 196          NaN         NaN            1.516         NaN
# 803          NaN         NaN            3.534         NaN
# 902          NaN         NaN            0.600         NaN
# 1003         NaN         NaN            0.600         NaN
# 1004         NaN         NaN            0.600         NaN
# 1005         NaN         NaN            2.405         NaN
# 1008         NaN         NaN            0.885         NaN
# 1010         NaN         NaN            0.600         NaN
# 1011         NaN         NaN            1.513         NaN
# 1012         NaN         NaN            0.606         NaN
# 1084         NaN         NaN            0.603         NaN
# 1093         NaN         NaN            0.600         NaN
# 1104         NaN         NaN            0.600         NaN
# 1110         NaN         NaN            1.268         NaN
# 1118         NaN         NaN            0.604         NaN
# 1122         NaN         NaN            0.600         NaN
# 1123         NaN         NaN            0.857         NaN
# 1124         NaN         NaN            0.600         NaN
# 1127         NaN         NaN            1.720         NaN
# 1129         NaN         NaN            0.600         NaN
# 1130         NaN         NaN            0.600         NaN
# 1132         NaN         NaN            1.217         NaN
# 1133         NaN         NaN            0.930         NaN
# 1134         NaN         NaN            0.600         NaN
# 1135         NaN         NaN            3.225         NaN
# 1164         NaN         NaN            1.358         NaN
# 1172         NaN         NaN            0.875         NaN
# 1202         NaN         NaN            0.600         NaN
# 1235         NaN         NaN            1.828         NaN
# 1253         NaN         NaN            3.842         NaN
# 1270         NaN         NaN            0.874         NaN
# 1293         NaN         NaN            1.245         NaN
# 1301         NaN         NaN            1.408         NaN
# 1307         NaN         NaN            1.981         NaN
# 1309         NaN         NaN            1.094         NaN
# 1312         NaN         NaN            1.532         NaN
# 1319         NaN         NaN            0.637         NaN
# 1320         NaN         NaN            1.464         NaN
# 1332         NaN         NaN            2.744         NaN
# 1333         NaN         NaN            0.600         NaN
# 1345         NaN         NaN            1.461         NaN
# 1347         NaN         NaN            0.959         NaN
# 1349         NaN         NaN            1.219         NaN
# 1353         NaN         NaN            2.463         NaN
# 1390         NaN         NaN            7.350         NaN
# 1433         NaN         NaN            1.562         NaN
# 1440         NaN         NaN            1.400         NaN
# 1453         NaN         NaN            0.600         NaN
# 1480         NaN         NaN            1.183         NaN
# 1482         NaN         NaN            0.764         NaN
# 1489         NaN         NaN            1.525         NaN
# 1494         NaN         NaN            1.976         NaN
# 1510         NaN         NaN            1.400         NaN
# 1519         NaN         NaN            1.960         NaN
# 1526         NaN         NaN            1.400         NaN
# 1528         NaN         NaN            1.761         NaN

# %%
# 보간 후 컬럼별 결측치 총합
disney_data.isnull().sum()
# Out:
# id                   0
# title                0
# type                 0
# release_year         0
# genres               0
# seasons              0
# imdb_score          58
# imdb_votes         427
# tmdb_popularity      6
# tmdb_score          58
# dtype: int64

# %%
# 몇 가지 컨텐츠를 직접 imdb와 tmdb에 넣어본 결과 대체로 진짜 점수가 없는 경우가 대다수였다.
# 인기있는 컨텐츠를 뽑을 때 score들이 없는 컨텐츠는 그만큼 인기가 없는 것이라 판단하고 결측치 제거
disney_data = disney_data.dropna(subset=['imdb_score', 'tmdb_score']).reset_index(drop=True)
print(disney_data.shape)
disney_data.isnull().sum()
# Out:
# (1471, 10)
# id                   0
# title                0
# type                 0
# release_year         0
# genres               0
# seasons              0
# imdb_score           0
# imdb_votes         369
# tmdb_popularity      6
# tmdb_score           0
# dtype: int64

# %%
disney_data
# Out:
#              id                                   title   type  release_year  \
# 0       tm74391                                Fantasia  MOVIE          1940
# 1       tm67803         Snow White and the Seven Dwarfs  MOVIE          1937
# 2       tm82546                               Pinocchio  MOVIE          1940
# 3       tm79357                                   Bambi  MOVIE          1942
# 4       tm62671                         Treasure Island  MOVIE          1950
# ...         ...                                     ...    ...           ...
# 1466   tm999348                            Own the Room  MOVIE          2021
# 1467  tm1002614  Built for Mars: The Perseverance Rover  MOVIE          2021
# 1468  tm1071287           Killer Shark vs. Killer Whale  MOVIE          2021
# 1469  tm1091101                   Far From Raven's Home  MOVIE          2021
# 1470  tm1133820                         The Magic Maker  MOVIE          2021
#
#                                                  genres  seasons  imdb_score  \
# 0           ['animation', 'family', 'music', 'fantasy']      0.0         7.7
# 1     ['fantasy', 'family', 'romance', 'animation', ...      0.0         7.6
# 2          ['animation', 'comedy', 'family', 'fantasy']      0.0         7.5
# 3                      ['animation', 'drama', 'family']      0.0         7.3
# 4                                  ['family', 'action']      0.0         6.9
# ...                                                 ...      ...         ...
# 1466                                  ['documentation']      0.0         6.5
# 1467                                  ['documentation']      0.0         6.9
# 1468                                  ['documentation']      0.0         6.4
# 1469                            ['animation', 'comedy']      0.0         5.6
# 1470                                                 []      0.0         4.2
#
#       imdb_votes  tmdb_popularity  tmdb_score
# 0        94681.0           57.751         7.4
# 1       195321.0          107.137         7.1
# 2       141937.0           71.160         7.1
# 3       140406.0           68.136         7.0
# 4         8229.0           10.698         6.5
# ...          ...              ...         ...
# 1466       223.0            3.544         6.4
# 1467        54.0            2.969         6.3
# 1468        17.0            1.061         4.0
# 1469         8.0            0.744        10.0
# 1470         9.0            1.504         4.2
#
# [1471 rows x 10 columns]

# %%
# imdb score 상위 10개
top_imdbscore=disney_data.sort_values('imdb_score',ascending=False)
top_imdbscore.head(10)
# Out:
#              id                                title   type  release_year  \
# 769   tm1104511       Return of the Clouded Leopards  MOVIE          2012
# 1259   ts269854          Disney Parks Sunrise Series   SHOW          2020
# 1268   ts251052        Disney Junior Music Lullabies   SHOW          2019
# 1278   ts255188                 Calling All T.O.T.S.   SHOW          2020
# 1309   tm973637             From Our Family to Yours  MOVIE          2020
# 1002    ts84270                                Bluey   SHOW          2018
# 1276   tm853361  Women of Impact: Changing the World  MOVIE          2020
# 1150   ts280148                   The Wizard of Paws   SHOW          2020
# 814    ts301931          Cosmos: A Spacetime Odyssey   SHOW          2014
# 1121   ts301932              Cosmos: Possible Worlds   SHOW          2020
#
#                                                genres  seasons  imdb_score  \
# 769                                 ['documentation']      0.0        10.0
# 1259                                               []      1.0        10.0
# 1268                                               []      1.0        10.0
# 1278                                               []      2.0        10.0
# 1309                           ['drama', 'animation']      0.0        10.0
# 1002                          ['animation', 'family']      3.0         9.7
# 1276                                ['documentation']      0.0         9.5
# 1150                            ['family', 'reality']      2.0         9.4
# 814                                 ['documentation']      1.0         9.3
# 1121  ['documentation', 'drama', 'thriller', 'scifi']      1.0         9.1
#
#       imdb_votes  tmdb_popularity  tmdb_score
# 769          NaN            0.600        10.0
# 1259         NaN            0.953        10.0
# 1268         NaN            0.600        10.0
# 1278         NaN            5.175        10.0
# 1309         NaN            1.400        10.0
# 1002      6626.0           32.210         7.0
# 1276         NaN            3.319         9.5
# 1150        30.0            1.519         9.4
# 814     119455.0              NaN         9.3
# 1121      5944.0            1.960        10.0

# %%
# 결측치 처리 전 imdb score 상위 10개
before_top_imdbscore=disney1.sort_values('imdb_score',ascending=False)
before_top_imdbscore.head(10)
# Out:
#              id                             title   type  \
# 1015    ts84270                             Bluey   SHOW
# 1182   ts280148                The Wizard of Paws   SHOW
# 819    ts301931       Cosmos: A Spacetime Odyssey   SHOW
# 1151   ts301932           Cosmos: Possible Worlds   SHOW
# 1252   ts238237              Alaska Animal Rescue   SHOW
# 1367   ts299852             The Beatles: Get Back   SHOW
# 1476   ts301923          The Hatcher Family Dairy   SHOW
# 1468  tm1168196  ASSEMBLED: The Making of Hawkeye  MOVIE
# 1415   ts331520                 Something Bit Me!   SHOW
# 1184   ts225082               Heartland Docs, DVM   SHOW
#
#                                             description  release_year  \
# 1015  Bluey is an inexhaustible six year-old Blue He...          2018
# 1182  Derrick Campana of Bionic Pets makes prostheti...          2020
# 819   An exploration of our discovery of the laws of...          2014
# 1151  Following the wildly successful "Cosmos: A Spa...          2020
# 1252  Dedicated first responders, veterinarians and ...          2020
# 1367  Documentary about the music group The Beatles ...          2021
# 1476  The Hatcher family continues to operate a 175-...          2021
# 1468  Join the likes of Jeremy Renner, Hailee Steinf...          2022
# 1415  The series explores the peculiar true stories ...          2022
# 1184  In picturesque rural Nebraska, the husband and...          2020
#
#      age_certification  runtime  \
# 1015              TV-Y        7
# 1182               NaN       22
# 819              TV-PG       43
# 1151             TV-PG       43
# 1252               NaN       44
# 1367               NaN      156
# 1476               NaN       44
# 1468             PG-13       59
# 1415             TV-14       43
# 1184             TV-PG       44
#
#                                                genres production_countries  \
# 1015                          ['animation', 'family']               ['AU']
# 1182                            ['family', 'reality']               ['US']
# 819                                 ['documentation']         ['FR', 'PT']
# 1151  ['documentation', 'drama', 'thriller', 'scifi']               ['US']
# 1252                     ['reality', 'documentation']               ['US']
# 1367                       ['documentation', 'music']   ['NZ', 'GB', 'US']
# 1476                                ['documentation']               ['US']
# 1468                                ['documentation']               ['US']
# 1415                     ['documentation', 'reality']               ['US']
# 1184                                      ['reality']               ['US']
#
#       seasons     imdb_id  imdb_score  imdb_votes  tmdb_popularity  tmdb_score
# 1015      3.0   tt7678620         9.7      6626.0           32.210         7.0
# 1182      2.0  tt13897634         9.4        30.0            1.519         NaN
# 819       1.0   tt2395695         9.3    119455.0              NaN         NaN
# 1151      1.0  tt11170862         9.1      5944.0            1.960        10.0
# 1252      2.0  tt12188528         9.0        36.0            1.790        10.0
# 1367      1.0   tt9735318         9.0     19391.0           13.597         8.5
# 1476      1.0  tt15058696         8.9        53.0            0.674         NaN
# 1468      NaN  tt14235904         8.8         NaN           16.685         6.4
# 1415      1.0  tt18334866         8.8        14.0           16.176        10.0
# 1184      4.0  tt11783490         8.8       112.0            4.447         8.0

# %%
fig = plt.figure(figsize=(10,7))

plt.subplot(1,2,1)
# imdb scores 상위 10개 그래프(수치 표시)
x = top_imdbscore.head(10)['title']
y = top_imdbscore.head(10)['imdb_score']
bar = plt.bar(x, y, alpha=0.5)
plt.ylim(0, 12)

# 숫자 넣는 부분
for rect in bar:
    height = rect.get_height()
    plt.text(rect.get_x() + rect.get_width()/2.0, height, '%.1f' % height, ha='center', va='bottom', size = 12)
    
plt.xticks(rotation=90)
plt.title("Top10 IMDB score in Disney+",fontweight="bold")

plt.subplot(1,2,2)
# 결측치 제거 전 imdb scores top 10(수치 표시)
x = before_top_imdbscore.head(10)['title']
y = before_top_imdbscore.head(10)['imdb_score']
bar = plt.bar(x, y, alpha=0.5)
plt.ylim(0, 12)

# 숫자 넣는 부분
for rect in bar:
    height = rect.get_height()
    plt.text(rect.get_x() + rect.get_width()/2.0, height, '%.1f' % height, ha='center', va='bottom', size = 12)
    
plt.xticks(rotation=90)
plt.title("Top10 IMDB score in Disney+ Before Data Disney+",fontweight="bold")

plt.tight_layout()
plt.show()

# %%
# imdb votes 상위 10개
top_imdbvotes=disney_data.sort_values('imdb_votes',ascending=False)
top_imdbvotes.head(10)
# Out:
#            id                                              title   type  \
# 721   tm64957                                       The Avengers  MOVIE
# 85        tm1                                          Star Wars  MOVIE
# 93        tm2                            The Empire Strikes Back  MOVIE
# 418  tm135853                                             Avatar  MOVIE
# 813  tm140097                            Guardians of the Galaxy  MOVIE
# 431   tm25151                                             WALL·E  MOVIE
# 417  tm133512  Pirates of the Caribbean: The Curse of the Bla...  MOVIE
# 429   tm51227                                           Iron Man  MOVIE
# 287  tm113629                                      The Lion King  MOVIE
# 216       tm3                                 Return of the Jedi  MOVIE
#
#      release_year                                             genres  seasons  \
# 721          2012                                ['scifi', 'action']      0.0
# 85           1977                     ['scifi', 'action', 'fantasy']      0.0
# 93           1980                     ['scifi', 'action', 'fantasy']      0.0
# 418          2009                     ['fantasy', 'scifi', 'action']      0.0
# 813          2014                      ['action', 'comedy', 'scifi']      0.0
# 431          2008  ['scifi', 'family', 'fantasy', 'romance', 'ani...      0.0
# 417          2003                              ['fantasy', 'action']      0.0
# 429          2008                                ['action', 'scifi']      0.0
# 287          1994                   ['drama', 'family', 'animation']      0.0
# 216          1983                     ['action', 'scifi', 'fantasy']      0.0
#
#      imdb_score  imdb_votes  tmdb_popularity  tmdb_score
# 721         8.0   1353907.0          262.184         7.7
# 85          8.6   1321489.0           77.321         8.2
# 93          8.7   1248319.0           27.802         8.4
# 418         7.8   1193331.0          598.284         7.5
# 813         8.0   1125382.0           70.546         7.9
# 431         8.4   1083424.0           75.615         8.1
# 417         8.0   1081867.0          484.892         7.8
# 429         7.9   1026464.0          116.448         7.6
# 287         8.5   1023813.0          145.278         8.3
# 216         8.3   1019886.0           26.537         7.9

# %%
# imdb votes top 10(수치 표시)
x = top_imdbvotes.head(10)['title']
y = top_imdbvotes.head(10)['imdb_votes']
bar = plt.bar(x, y, alpha=0.5)

# 숫자 넣는 부분
for rect in bar:
    height = rect.get_height()
    plt.text(rect.get_x() + rect.get_width()/2.0, height, '%.1f' % height, ha='center', va='bottom', size = 6)
    
plt.xticks(rotation=90)
plt.title("Top10 IMDB votes in Disney+",fontweight="bold")

plt.show()

# %%
# tmdb popularity 상위 10개
top_tmdbpopularity=disney_data.sort_values('tmdb_popularity',ascending=False)
top_tmdbpopularity.head(10)
# Out:
#             id                                       title   type  \
# 1313  ts219003                                 Moon Knight   SHOW
# 1317  tm375923                                 Turning Red  MOVIE
# 901   tm123360                              Doctor Strange  MOVIE
# 1321  tm858873                                     Encanto  MOVIE
# 1352  tm989857         The Ice Age Adventures of Buck Wild  MOVIE
# 1326  tm821207   Shang-Chi and the Legend of the Ten Rings  MOVIE
# 1322  tm439804                                    Eternals  MOVIE
# 425    tm31764  Pirates of the Caribbean: Dead Man's Chest  MOVIE
# 418   tm135853                                      Avatar  MOVIE
# 437    tm84873    Pirates of the Caribbean: At World's End  MOVIE
#
#       release_year                                             genres  \
# 1313          2022  ['action', 'scifi', 'drama', 'fantasy', 'horro...
# 1317          2022       ['fantasy', 'comedy', 'family', 'animation']
# 901           2016                     ['fantasy', 'action', 'scifi']
# 1321          2021  ['fantasy', 'animation', 'comedy', 'family', '...
# 1352          2022  ['comedy', 'drama', 'action', 'animation', 'fa...
# 1326          2021  ['fantasy', 'documentation', 'action', 'scifi'...
# 1322          2021            ['scifi', 'action', 'fantasy', 'drama']
# 425           2006                              ['fantasy', 'action']
# 418           2009                     ['fantasy', 'scifi', 'action']
# 437           2007                              ['fantasy', 'action']
#
#       seasons  imdb_score  imdb_votes  tmdb_popularity  tmdb_score
# 1313      1.0         7.5    128362.0         9323.832         8.5
# 1317      0.0         7.0     90356.0         2331.811         7.4
# 901       0.0         7.5    697884.0         2286.312         7.4
# 1321      0.0         7.2    194310.0         1174.064         7.7
# 1352      0.0         4.5     11952.0         1026.354         6.9
# 1326      0.0         7.5    324679.0          818.481         7.7
# 1322      0.0         6.3    300591.0          656.899         7.1
# 425       0.0         7.3    697579.0          635.656         7.3
# 418       0.0         7.8   1193331.0          598.284         7.5
# 437       0.0         7.1    633813.0          570.745         7.2

# %%
# tmdb popularity top 10(수치 표시)
x = top_tmdbpopularity.head(10)['title']
y = top_tmdbpopularity.head(10)['tmdb_popularity']
bar = plt.bar(x, y, alpha=0.5)

# 숫자 넣는 부분
for rect in bar:
    height = rect.get_height()
    plt.text(rect.get_x() + rect.get_width()/2.0, height, '%.1f' % height, ha='center', va='bottom', size = 6)
    
plt.xticks(rotation=90)
plt.title("Top10 TMDB popularity in Disney+",fontweight="bold")

plt.show()

# %%
# tmdb score 상위 10개
top_tmdbscore=disney_data.sort_values('tmdb_score',ascending=False)
top_tmdbscore.head(10)
# Out:
#             id                                        title  type  \
# 1218  ts238237                         Alaska Animal Rescue  SHOW
# 1409  ts258072                        Mickey Mouse Funhouse  SHOW
# 1369  ts272714       Cesar Millan: Better Human, Better Dog  SHOW
# 1121  ts301932                      Cosmos: Possible Worlds  SHOW
# 1363  ts331520                            Something Bit Me!  SHOW
# 1359  ts270701                                   Dino Ranch  SHOW
# 1145  ts252988             Life Below Zero: Next Generation  SHOW
# 1173  ts223011  Buried Secrets of The Bible With Albert Lin  SHOW
# 1200  ts286382                    Secrets of the Zoo: Tampa  SHOW
# 348    ts25438                               Out of the Box  SHOW
#
#       release_year                                             genres  \
# 1218          2020                       ['reality', 'documentation']
# 1409          2021  ['family', 'fantasy', 'romance', 'animation', ...
# 1369          2021                                        ['reality']
# 1121          2020    ['documentation', 'drama', 'thriller', 'scifi']
# 1363          2022                       ['documentation', 'reality']
# 1359          2021  ['action', 'family', 'western', 'animation', '...
# 1145          2020                                        ['reality']
# 1173          2019                       ['documentation', 'history']
# 1200          2020                        ['documentation', 'family']
# 348           1998  ['music', 'comedy', 'family', 'fantasy', 'spor...
#
#       seasons  imdb_score  imdb_votes  tmdb_popularity  tmdb_score
# 1218      2.0         9.0        36.0            1.790        10.0
# 1409      5.0         5.2       135.0           14.486        10.0
# 1369      1.0         8.2       110.0            1.400        10.0
# 1121      1.0         9.1      5944.0            1.960        10.0
# 1363      1.0         8.8        14.0           16.176        10.0
# 1359      1.0         6.2       106.0            3.809        10.0
# 1145      4.0         5.2       214.0            1.651        10.0
# 1173      1.0         6.8       188.0            2.024        10.0
# 1200      3.0         8.7        66.0            1.400        10.0
# 348       3.0         7.4       990.0            2.063        10.0

# %%
# 결측치 처리 전 tmdb votes 상위 10개
before_top_tmdbscore=disney1.sort_values('tmdb_score',ascending=False)
before_top_tmdbscore.head(10)
# Out:
#              id                                   title   type  \
# 1531  tm1091101                   Far From Raven's Home  MOVIE
# 1307   ts251052           Disney Junior Music Lullabies   SHOW
# 1250   ts225533                      Wild Cats of India   SHOW
# 1252   ts238237                    Alaska Animal Rescue   SHOW
# 1278    ts94668                       Prairie Dog Manor   SHOW
# 1284   ts112728                           The Rocketeer   SHOW
# 1421   ts272714  Cesar Millan: Better Human, Better Dog   SHOW
# 1296   ts269854             Disney Parks Sunrise Series   SHOW
# 1320   ts255188                    Calling All T.O.T.S.   SHOW
# 1233   ts286382               Secrets of the Zoo: Tampa   SHOW
#
#                                             description  release_year  \
# 1531  Our gang is off for an exotic vacation of a li...          2021
# 1307  Mickey Mouse, Minnie Mouse, Doc McStuffins, Fa...          2019
# 1250  India's wildcats have been symbols of strength...          2020
# 1252  Dedicated first responders, veterinarians and ...          2020
# 1278  "Prairie Dog Manor" gives an in depth look at ...          2019
# 1284  A girl inherits the persona of The Rocketeer, ...          2019
# 1421  Showcases Cesar Millan as he takes on the most...          2021
# 1296  At daybreak, the first rays of sunlight gleam ...          2020
# 1320  T.O.T.S. Junior Fliers, Pip and Freddy love no...          2020
# 1233  Embrace the wild side of the Sunshine State wi...          2020
#
#      age_certification  runtime  \
# 1531                 G       11
# 1307              TV-Y        1
# 1250               NaN       44
# 1252               NaN       44
# 1278               NaN       22
# 1284              TV-Y       23
# 1421             TV-14       42
# 1296              TV-G       59
# 1320              TV-G        2
# 1233             TV-14       44
#
#                                                  genres production_countries  \
# 1531                            ['animation', 'comedy']                   []
# 1307                                                 []               ['US']
# 1250                                  ['documentation']               ['IN']
# 1252                       ['reality', 'documentation']               ['US']
# 1278                       ['reality', 'documentation']               ['US']
# 1284  ['scifi', 'animation', 'action', 'comedy', 'fa...               ['US']
# 1421                                        ['reality']               ['US']
# 1296                                                 []               ['US']
# 1320                                                 []               ['PH']
# 1233                        ['documentation', 'family']               ['US']
#
#       seasons     imdb_id  imdb_score  imdb_votes  tmdb_popularity  tmdb_score
# 1531      NaN  tt15489328         5.6         8.0            0.744        10.0
# 1307      1.0         NaN         NaN         NaN            0.600        10.0
# 1250      1.0  tt11920706         7.6        44.0            1.400        10.0
# 1252      2.0  tt12188528         9.0        36.0            1.790        10.0
# 1278      1.0   tt8316986         8.0        48.0            1.494        10.0
# 1284      1.0   tt8068852         4.9       171.0           11.641        10.0
# 1421      1.0  tt15083978         8.2       110.0            1.400        10.0
# 1296      1.0         NaN         NaN         NaN            0.953        10.0
# 1320      2.0         NaN         NaN         NaN            5.175        10.0
# 1233      3.0  tt11708046         8.7        66.0            1.400        10.0

# %%
fig = plt.figure(figsize=(10,7))

plt.subplot(1,2,1)
# tmdb scores top 10(수치 표시)
x = top_tmdbscore.head(10)['title']
y = top_tmdbscore.head(10)['tmdb_score']
bar = plt.bar(x, y, alpha=0.5)
plt.ylim(0, 12)

# 숫자 넣는 부분
for rect in bar:
    height = rect.get_height()
    plt.text(rect.get_x() + rect.get_width()/2.0, height, '%.1f' % height, ha='center', va='bottom', size = 12)
    
plt.xticks(rotation=90)
plt.title("Top10 TMDB score in Disney+",fontweight="bold")



plt.subplot(1,2,2)
# tmdb scores top 10(수치 표시)
x = before_top_tmdbscore.head(10)['title']
y = before_top_tmdbscore.head(10)['tmdb_score']
bar = plt.bar(x, y, alpha=0.5)
plt.ylim(0, 12)

# 숫자 넣는 부분
for rect in bar:
    height = rect.get_height()
    plt.text(rect.get_x() + rect.get_width()/2.0, height, '%.1f' % height, ha='center', va='bottom', size = 12)
    
plt.xticks(rotation=90)
plt.title("Top10 TMDB score in Disney+ Before Data Preprocessing",fontweight="bold")

plt.tight_layout()
plt.show()

# %% [markdown]
# --------

# %% [markdown]
# ### 디즈니 영화와 쇼 비교

# %%
sns.countplot(x='type', data=disney)
plt.title("Comparison of Type")
plt.show()

# %% [markdown]
# ### 디즈니 영화 연도별 분류

# %%
disney_movies= disney[disney["type"]== "MOVIE"]
disney_movies.head()
# Out:
#         id                            title   type  \
# 0  tm74391                         Fantasia  MOVIE
# 1  tm67803  Snow White and the Seven Dwarfs  MOVIE
# 2  tm82546                        Pinocchio  MOVIE
# 3  tm79357                            Bambi  MOVIE
# 4  tm62671                  Treasure Island  MOVIE
#
#                                          description  release_year  \
# 0  Walt Disney's timeless masterpiece is an extra...          1940
# 1  A beautiful girl, Snow White, takes refuge in ...          1937
# 2  Lonely toymaker Geppetto has his wishes answer...          1940
# 3  Bambi's tale unfolds from season to season as ...          1942
# 4  Enchanted by the idea of locating treasure bur...          1950
#
#   age_certification  runtime  \
# 0                 G      120
# 1                 G       83
# 2                 G       88
# 3                 G       70
# 4                PG       96
#
#                                               genres production_countries  \
# 0        ['animation', 'family', 'music', 'fantasy']               ['US']
# 1  ['fantasy', 'family', 'romance', 'animation', ...               ['US']
# 2       ['animation', 'comedy', 'family', 'fantasy']               ['US']
# 3                   ['animation', 'drama', 'family']               ['US']
# 4                               ['family', 'action']         ['GB', 'US']
#
#    seasons    imdb_id  imdb_score  imdb_votes  tmdb_popularity  tmdb_score
# 0      0.0  tt0032455         7.7     94681.0           57.751         7.4
# 1      0.0  tt0029583         7.6    195321.0          107.137         7.1
# 2      0.0  tt0032910         7.5    141937.0           71.160         7.1
# 3      0.0  tt0034492         7.3    140406.0           68.136         7.0
# 4      0.0  tt0043067         6.9      8229.0           10.698         6.5

# %%
disney_movies["release_year"].value_counts()
# Out:
# 2020    78
# 2021    76
# 2019    53
# 2014    38
# 2017    35
#         ..
# 1928     1
# 1973     1
# 1970     1
# 1943     1
# 1958     1
# Name: release_year, Length: 91, dtype: int64

# %%
plt.figure(figsize=(14,8))
plt.xticks(rotation = 90)

sns.countplot(x='release_year', data=disney_movies)
plt.title("Movies by release year")
plt.show()

# %% [markdown]
# ### 디즈니 쇼 연도별 분류

# %%
disney_show = disney[disney["type"]=="SHOW"]
disney_show
# Out:
#             id                                  title  type  \
# 86     ts22470                        The Muppet Show  SHOW
# 92     ts30718                      Schoolhouse Rock!  SHOW
# 109    ts28051                  The Mickey Mouse Club  SHOW
# 120    ts24939                           Spider-Woman  SHOW
# 140    ts27944                         Spin and Marty  SHOW
# ...        ...                                    ...   ...
# 1503  ts273161                             Foodtastic  SHOW
# 1510  ts272675                   Breaking Bobby Bones  SHOW
# 1516  ts271728               The Wild Life of Dr. Ole  SHOW
# 1518  ts288962  Turning the Tables with Robin Roberts  SHOW
# 1519  ts313961                      Vets on the Beach  SHOW
#
#                                             description  release_year  \
# 86    Go behind the curtains as Kermit the Frog and ...          1976
# 92    Schoolhouse Rock! is an American interstitial ...          1973
# 109   A variety show featuring a cast of child perfo...          1955
# 120   When Jessica Drew was bitten by a poisonous sp...          1979
# 140   Spin and Marty is a popular series of televisi...          1955
# ...                                                 ...           ...
# 1503  Three teams of food artists transform iconic c...          2021
# 1510  Bobby Bones crisscrosses the country to meet e...          2021
# 1516  Dr. Ole Alcumbrac owns White Mountain Animal H...          2021
# 1518  Get personal with Robin Roberts and some of Ho...          2021
# 1519  Four vets from across Australia come together ...          2021
#
#      age_certification  runtime                                        genres  \
# 86                TV-G       25                 ['comedy', 'family', 'music']
# 92                 NaN        3                       ['animation', 'family']
# 109              TV-PG       31        ['family', 'music', 'comedy', 'drama']
# 120              TV-PG       21  ['animation', 'fantasy', 'action', 'family']
# 140                NaN       12                         ['western', 'family']
# ...                ...      ...                                           ...
# 1503             TV-PG       42                                   ['reality']
# 1510             TV-14       22                             ['documentation']
# 1516             TV-PG       44                  ['documentation', 'reality']
# 1518               NaN       27                                            []
# 1519             TV-PG       44                             ['documentation']
#
#      production_countries  seasons     imdb_id  imdb_score  imdb_votes  \
# 86                 ['GB']      5.0   tt0074028         8.4     24278.0
# 92                 ['US']      7.0   tt0069627         8.2      3905.0
# 109                ['US']      3.0   tt0047757         7.6       779.0
# 120                ['US']      1.0   tt0197911         5.8       790.0
# 140                ['US']      1.0   tt0047775         8.0       300.0
# ...                   ...      ...         ...         ...         ...
# 1503               ['US']      1.0  tt13644666         4.8       155.0
# 1510               ['US']      1.0         NaN         NaN         NaN
# 1516               ['US']      1.0  tt14232200         8.4        19.0
# 1518               ['US']      1.0  tt14598810         5.7        39.0
# 1519                   []      1.0         NaN         NaN         NaN
#
#       tmdb_popularity  tmdb_score
# 86             12.641         8.1
# 92              2.987         7.8
# 109             7.194         5.8
# 120            19.081         8.0
# 140             2.866         8.0
# ...               ...         ...
# 1503            2.344         1.0
# 1510            1.400         NaN
# 1516            1.400         NaN
# 1518            1.955         NaN
# 1519            1.960         NaN
#
# [411 rows x 15 columns]

# %%
disney_show["release_year"].value_counts()
# Out:
# 2021    59
# 2020    47
# 2019    42
# 2017    31
# 2018    26
# 2015    25
# 2016    22
# 2014    15
# 2012    15
# 2013    15
# 2022    12
# 2011    12
# 2010     8
# 2009     7
# 2008     5
# 2006     5
# 1998     4
# 2007     4
# 1992     4
# 1997     4
# 1994     4
# 2004     4
# 2001     3
# 2005     3
# 2003     3
# 1996     3
# 1999     3
# 2000     3
# 1991     3
# 1989     3
# 1985     3
# 1955     2
# 1993     2
# 1981     2
# 1973     1
# 1987     1
# 1979     1
# 1988     1
# 1990     1
# 2002     1
# 1995     1
# 1976     1
# Name: release_year, dtype: int64

# %%
plt.figure(figsize=(14,8))
plt.xticks(rotation = 90)

sns.countplot(x='release_year', data=disney_show)
plt.title("Show count by release year")
plt.show()

# %% [markdown]
# ### 장르별 분류

# %%
# 영화 장르 분류
disney_m_genres = disney_movies[['genres']]
disney_m_genres
# Out:
#                                                  genres
# 0           ['animation', 'family', 'music', 'fantasy']
# 1     ['fantasy', 'family', 'romance', 'animation', ...
# 2          ['animation', 'comedy', 'family', 'fantasy']
# 3                      ['animation', 'drama', 'family']
# 4                                  ['family', 'action']
# ...                                                 ...
# 1524                                  ['documentation']
# 1525                            ['animation', 'comedy']
# 1526                                  ['documentation']
# 1527                                                 []
# 1528                                  ['documentation']
#
# [1118 rows x 1 columns]

# %%
disney_m_genres["genres"].value_counts()
# Out:
# ['documentation']                                         150
# ['animation']                                             112
# ['comedy']                                                 58
# ['fantasy']                                                20
# ['comedy', 'family']                                       18
#                                                          ...
# ['fantasy', 'scifi', 'action', 'family']                    1
# ['scifi', 'action', 'fantasy', 'european']                  1
# ['scifi', 'family', 'fantasy', 'romance', 'animation']      1
# ['fantasy', 'family', 'documentation']                      1
# ['documentation', 'animation']                              1
# Name: genres, Length: 457, dtype: int64

# %%
# [] 장르가 비어있는 행 삭제
idx1 = disney_m_genres[disney_m_genres['genres'] == '[]'].index
disney_m_genres.drop(idx1, inplace=True)
disney_m_genres
# Out:
# /var/folders/4q/5nms447x5r73lpjnv48256k80000gn/T/ipykernel_8594/3238323891.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   disney_m_genres.drop(idx1, inplace=True)
#                                                  genres
# 0           ['animation', 'family', 'music', 'fantasy']
# 1     ['fantasy', 'family', 'romance', 'animation', ...
# 2          ['animation', 'comedy', 'family', 'fantasy']
# 3                      ['animation', 'drama', 'family']
# 4                                  ['family', 'action']
# ...                                                 ...
# 1523                                  ['documentation']
# 1524                                  ['documentation']
# 1525                            ['animation', 'comedy']
# 1526                                  ['documentation']
# 1528                                  ['documentation']
#
# [1108 rows x 1 columns]

# %%
disney_m_genres["genres"] = disney_m_genres['genres'].str.replace(pat=r'[', repl=r'', regex=True)
# Out:
# /var/folders/4q/5nms447x5r73lpjnv48256k80000gn/T/ipykernel_8594/2635446078.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   disney_m_genres["genres"] = disney_m_genres['genres'].str.replace(pat=r'[', repl=r'', regex=True)

# %%
disney_m_genres["genres"] = disney_m_genres['genres'].str.replace(pat=r']', repl=r'', regex=True)
disney_m_genres
# Out:
# /var/folders/4q/5nms447x5r73lpjnv48256k80000gn/T/ipykernel_8594/3726940998.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   disney_m_genres["genres"] = disney_m_genres['genres'].str.replace(pat=r']', repl=r'', regex=True)
#                                                  genres
# 0             'animation', 'family', 'music', 'fantasy'
# 1     'fantasy', 'family', 'romance', 'animation', '...
# 2            'animation', 'comedy', 'family', 'fantasy'
# 3                        'animation', 'drama', 'family'
# 4                                    'family', 'action'
# ...                                                 ...
# 1523                                    'documentation'
# 1524                                    'documentation'
# 1525                              'animation', 'comedy'
# 1526                                    'documentation'
# 1528                                    'documentation'
#
# [1108 rows x 1 columns]

# %%
disney_m_genres['genres'] = disney_m_genres['genres'].apply(lambda x: x.split(",")[0])

print(disney_m_genres.shape)
disney_m_genres
# Out:
# (1108, 1)
# /var/folders/4q/5nms447x5r73lpjnv48256k80000gn/T/ipykernel_8594/2474855801.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   disney_m_genres['genres'] = disney_m_genres['genres'].apply(lambda x: x.split(",")[0])
#                genres
# 0         'animation'
# 1           'fantasy'
# 2         'animation'
# 3         'animation'
# 4            'family'
# ...               ...
# 1523  'documentation'
# 1524  'documentation'
# 1525      'animation'
# 1526  'documentation'
# 1528  'documentation'
#
# [1108 rows x 1 columns]

# %%
plt.figure(figsize=(15,5))
sns.barplot(x = disney_m_genres["genres"].value_counts().head(10).index,
            y = disney_m_genres["genres"].value_counts().head(10).values)
plt.xticks(rotation=80)
plt.title("Top10 Genre in Movies",fontweight="bold")
plt.show()

# %%
# 쇼 장르 분류
disney_s_genres = disney_show[['genres']]
disney_s_genres
# Out:
#                                             genres
# 86                   ['comedy', 'family', 'music']
# 92                         ['animation', 'family']
# 109         ['family', 'music', 'comedy', 'drama']
# 120   ['animation', 'fantasy', 'action', 'family']
# 140                          ['western', 'family']
# ...                                            ...
# 1503                                   ['reality']
# 1510                             ['documentation']
# 1516                  ['documentation', 'reality']
# 1518                                            []
# 1519                             ['documentation']
#
# [411 rows x 1 columns]

# %%
disney_s_genres["genres"].value_counts()
# Out:
# ['documentation']                                                    70
# ['reality']                                                          17
# []                                                                   17
# ['comedy', 'family']                                                 12
# ['documentation', 'reality']                                         12
#                                                                      ..
# ['scifi', 'action', 'comedy', 'drama', 'family']                      1
# ['action', 'animation', 'family', 'fantasy']                          1
# ['comedy', 'drama', 'family', 'fantasy']                              1
# ['action', 'fantasy', 'scifi', 'animation', 'comedy', 'family']       1
# ['family', 'fantasy', 'romance', 'animation', 'comedy', 'action']     1
# Name: genres, Length: 216, dtype: int64

# %%
idx3 = disney_s_genres[disney_s_genres['genres'] == '[]'].index
disney_s_genres.drop(idx3, inplace=True)
disney_s_genres
# Out:
# /var/folders/4q/5nms447x5r73lpjnv48256k80000gn/T/ipykernel_8594/1233102764.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   disney_s_genres.drop(idx3, inplace=True)
#                                             genres
# 86                   ['comedy', 'family', 'music']
# 92                         ['animation', 'family']
# 109         ['family', 'music', 'comedy', 'drama']
# 120   ['animation', 'fantasy', 'action', 'family']
# 140                          ['western', 'family']
# ...                                            ...
# 1491             ['comedy', 'family', 'animation']
# 1503                                   ['reality']
# 1510                             ['documentation']
# 1516                  ['documentation', 'reality']
# 1519                             ['documentation']
#
# [394 rows x 1 columns]

# %%
disney_s_genres["genres"] = disney_s_genres['genres'].str.replace(pat=r'[', repl=r'', regex=True)
# Out:
# /var/folders/4q/5nms447x5r73lpjnv48256k80000gn/T/ipykernel_8594/3258505979.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   disney_s_genres["genres"] = disney_s_genres['genres'].str.replace(pat=r'[', repl=r'', regex=True)

# %%
disney_s_genres["genres"] = disney_s_genres['genres'].str.replace(pat=r']', repl=r'', regex=True)
disney_s_genres
# Out:
# /var/folders/4q/5nms447x5r73lpjnv48256k80000gn/T/ipykernel_8594/907737074.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   disney_s_genres["genres"] = disney_s_genres['genres'].str.replace(pat=r']', repl=r'', regex=True)
#                                           genres
# 86                   'comedy', 'family', 'music'
# 92                         'animation', 'family'
# 109         'family', 'music', 'comedy', 'drama'
# 120   'animation', 'fantasy', 'action', 'family'
# 140                          'western', 'family'
# ...                                          ...
# 1491             'comedy', 'family', 'animation'
# 1503                                   'reality'
# 1510                             'documentation'
# 1516                  'documentation', 'reality'
# 1519                             'documentation'
#
# [394 rows x 1 columns]

# %%
disney_s_genres['genres'] = disney_s_genres['genres'].apply(lambda x: x.split(",")[0])

print(disney_s_genres.shape)
disney_s_genres
# Out:
# (394, 1)
# /var/folders/4q/5nms447x5r73lpjnv48256k80000gn/T/ipykernel_8594/589825839.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   disney_s_genres['genres'] = disney_s_genres['genres'].apply(lambda x: x.split(",")[0])
#                genres
# 86           'comedy'
# 92        'animation'
# 109          'family'
# 120       'animation'
# 140         'western'
# ...               ...
# 1491         'comedy'
# 1503        'reality'
# 1510  'documentation'
# 1516  'documentation'
# 1519  'documentation'
#
# [394 rows x 1 columns]

# %%
plt.figure(figsize=(15,5))
sns.barplot(x = disney_s_genres["genres"].value_counts().head(10).index,
            y = disney_s_genres["genres"].value_counts().head(10).values)
plt.xticks(rotation=60)
plt.title("Top10 Genre in Show",fontweight="bold")
plt.show()

# %% [markdown]
# ### 제작 국가별 분류

# %%
disney_p_country = disney[['production_countries']]
disney_p_country
# Out:
#      production_countries
# 0                  ['US']
# 1                  ['US']
# 2                  ['US']
# 3                  ['US']
# 4            ['GB', 'US']
# ...                   ...
# 1524               ['US']
# 1525                   []
# 1526                   []
# 1527               ['US']
# 1528               ['US']
#
# [1529 rows x 1 columns]

# %%
# [] 국가명이 비어있는 행 삭제
idx2 = disney_p_country[disney_p_country['production_countries'] == '[]'].index
disney_p_country.drop(idx2, inplace=True)
disney_p_country
# Out:
# /var/folders/4q/5nms447x5r73lpjnv48256k80000gn/T/ipykernel_8594/3090316309.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   disney_p_country.drop(idx2, inplace=True)
#      production_countries
# 0                  ['US']
# 1                  ['US']
# 2                  ['US']
# 3                  ['US']
# 4            ['GB', 'US']
# ...                   ...
# 1522               ['US']
# 1523               ['US']
# 1524               ['US']
# 1527               ['US']
# 1528               ['US']
#
# [1485 rows x 1 columns]

# %%
disney_p_country["production_countries"] = disney_p_country['production_countries'].str.replace(pat=r'[', repl=r'', regex=True)
# Out:
# /var/folders/4q/5nms447x5r73lpjnv48256k80000gn/T/ipykernel_8594/1097084909.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   disney_p_country["production_countries"] = disney_p_country['production_countries'].str.replace(pat=r'[', repl=r'', regex=True)

# %%
disney_p_country["production_countries"] = disney_p_country['production_countries'].str.replace(pat=r']', repl=r'', regex=True)
disney_p_country
# Out:
# /var/folders/4q/5nms447x5r73lpjnv48256k80000gn/T/ipykernel_8594/1664739518.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   disney_p_country["production_countries"] = disney_p_country['production_countries'].str.replace(pat=r']', repl=r'', regex=True)
#      production_countries
# 0                    'US'
# 1                    'US'
# 2                    'US'
# 3                    'US'
# 4              'GB', 'US'
# ...                   ...
# 1522                 'US'
# 1523                 'US'
# 1524                 'US'
# 1527                 'US'
# 1528                 'US'
#
# [1485 rows x 1 columns]

# %%
disney_p_country['production_countries'] = disney_p_country['production_countries'].apply(lambda x: x.split(",")[0])

disney_p_country
# Out:
# /var/folders/4q/5nms447x5r73lpjnv48256k80000gn/T/ipykernel_8594/3150082608.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   disney_p_country['production_countries'] = disney_p_country['production_countries'].apply(lambda x: x.split(",")[0])
#      production_countries
# 0                    'US'
# 1                    'US'
# 2                    'US'
# 3                    'US'
# 4                    'GB'
# ...                   ...
# 1522                 'US'
# 1523                 'US'
# 1524                 'US'
# 1527                 'US'
# 1528                 'US'
#
# [1485 rows x 1 columns]

# %%
disney_p_country["production_countries"].value_counts()
# Out:
# 'US'      1318
# 'GB'        49
# 'CA'        34
# 'FR'        18
# 'AU'        12
# 'DE'         8
# 'JP'         5
# 'NZ'         5
# 'IN'         4
# 'AR'         4
# 'CN'         3
# 'MX'         3
# 'ES'         2
# 'PH'         2
# 'ZA'         2
# 'DK'         1
# 'IT'         1
# 'BW'         1
# 'GR'         1
# 'CL'         1
# 'BR'         1
# 'HK'         1
# 'BE'         1
# 'NL'         1
# 'CI'         1
# 'XX'         1
# 'SG'         1
# 'PL'         1
# 'SUHH'       1
# 'SE'         1
# 'KR'         1
# Name: production_countries, dtype: int64

# %%
plt.figure(figsize=(15,5))
sns.barplot(x = disney_p_country["production_countries"].value_counts().head(10).index,
            y = disney_p_country["production_countries"].value_counts().head(10).values)
plt.xticks(rotation=60)
plt.title("Top10 Countries of Production", fontweight="bold")
plt.show()

# %% [markdown]
# ### 연령 제한에 따른 분류

# %%
disney_age = disney[['age_certification']]
disney_age
# Out:
#      age_certification
# 0                    G
# 1                    G
# 2                    G
# 3                    G
# 4                   PG
# ...                ...
# 1524             PG-13
# 1525                 G
# 1526             PG-13
# 1527                PG
# 1528                PG
#
# [1529 rows x 1 columns]

# %%
# age_certification 결측치 있는 행 제거
disney_age = disney_age.dropna(subset=['age_certification']).reset_index(drop=True)
print(disney_age.shape)
disney_age.isnull().sum()
# Out:
# (1209, 1)
# age_certification    0
# dtype: int64

# %%
plt.figure(figsize=(14,8))

sns.countplot(x='age_certification', data=disney_age)
plt.title("Kind of Age Certification")
plt.show()

# %% [markdown]
# #### 영상물 등급 분류
# 1. 영화
# G : General (전체관람가)
# PG : 부모지도하 전체관람가
# PG-13 : 13세이상관람가(부모동반시 13세미만관람가능)
# R : 17세이상관람가(부모동반시 17세미만관람가능)
# NC-17 : 17세미만 관람불가
# 2. 드라마
# TV-Y : 전체 어린이 대상
# TV-Y7 : 7세이상 어린이 대상
# TV-G : 전체관람가
# TV-PG : 부모지도하 전체관람가
# TV-14 : 14세미만 시청부적절
# TV-MA : 성인대상, 17세미만 시청부적절

# %% [markdown]
# ### runtime에 따른 분류_영화

# %% [markdown]
# ## Reference
# [히스토그램](https://wikidocs.net/92112)
# [데이터프레임 속 괄호 지우기](https://velog.io/@yelim421/.replace%EB%A1%9C-%EC%9B%90%ED%95%98%EB%8A%94-%ED%8A%B9%EC%88%98%EB%AC%B8%EC%9E%90%EC%99%80-%EA%B4%84%ED%98%B8-%EC%95%88%EC%9D%98-%EB%82%B4%EC%9A%A9-%EC%A7%80%EC%9A%B0%EA%B8%B0)
# [전반적인 참고1](https://sks8410.tistory.com/64)
# [전반적인 참고2](https://stricky.tistory.com/454)
# [결측치 채우기](https://zephyrus1111.tistory.com/130)
# [막대그래프](https://benn.tistory.com/11)
# [데이터프레임합성](https://datascienceschool.net/01%20python/04.06%20%EB%8D%B0%EC%9D%B4%ED%84%B0%ED%94%84%EB%A0%88%EC%9E%84%20%ED%95%A9%EC%84%B1.html)
# [바그래프 수치표시](https://jimmy-ai.tistory.com/24)
# [subplot 간격](https://zephyrus1111.tistory.com/120)
