# %%
import pandas as pd
import os

path_credit=os.getcwd()+'/archive/credits.csv'
path_title=os.getcwd()+'/archive/titles.csv'
path_amazon=os.getcwd()+'/archive (2)/titles.csv'

credit=pd.read_csv(path_credit)
title=pd.read_csv(path_title)
amazon=pd.read_csv(path_amazon)

# %% [markdown]
# ### 결측치 확인

# %%
import numpy as np

title.isnull().sum()
# Out:
# id                         0
# title                      1
# type                       0
# description               18
# release_year               0
# age_certification       2619
# runtime                    0
# genres                     0
# production_countries       0
# seasons                 3744
# imdb_id                  403
# imdb_score               482
# imdb_votes               498
# tmdb_popularity           91
# tmdb_score               311
# dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10,6))
netflix_corr = sns.heatmap(title.corr(), annot=True, linewidths=0.5, cmap='RdBu_r')
netflix_corr.set_xticklabels(netflix_corr.get_xticklabels(), rotation=45)
netflix_corr.axes.set_title('Netflix data before Data Preprocessing', fontsize=20)
# Out:
# Text(0.5, 1.0, 'Netflix data before Data Preprocessing')

# %% [markdown]
# 지워도 되는 결측치들 :
#
# <title.csv>
#
# age_certification , product_countried, runtime, imdb_id,description

# %%
del title['production_countries']
del title['imdb_id']
del title['description']
title
# Out:
#              id                                      title   type  \
# 0      ts300399        Five Came Back: The Reference Films   SHOW
# 1       tm84618                                Taxi Driver  MOVIE
# 2      tm154986                                Deliverance  MOVIE
# 3      tm127384            Monty Python and the Holy Grail  MOVIE
# 4      tm120801                            The Dirty Dozen  MOVIE
# ...         ...                                        ...    ...
# 5845  tm1014599                                  Fine Wine  MOVIE
# 5846   tm898842                                C/O Kaadhal  MOVIE
# 5847  tm1059008                                    Lokillo  MOVIE
# 5848  tm1035612  Dad Stop Embarrassing Me - The Afterparty  MOVIE
# 5849   ts271048         Mighty Little Bheem: Kite Festival   SHOW
#
#       release_year age_certification  runtime  \
# 0             1945             TV-MA       51
# 1             1976                 R      114
# 2             1972                 R      109
# 3             1975                PG       91
# 4             1967               NaN      150
# ...            ...               ...      ...
# 5845          2021               NaN      100
# 5846          2021               NaN      134
# 5847          2021               NaN       90
# 5848          2021             PG-13       37
# 5849          2021               NaN        7
#
#                                            genres  seasons  imdb_score  \
# 0                               ['documentation']      1.0         NaN
# 1                              ['drama', 'crime']      NaN         8.2
# 2     ['drama', 'action', 'thriller', 'european']      NaN         7.7
# 3                 ['fantasy', 'action', 'comedy']      NaN         8.2
# 4                               ['war', 'action']      NaN         7.7
# ...                                           ...      ...         ...
# 5845                         ['romance', 'drama']      NaN         6.8
# 5846                                    ['drama']      NaN         7.7
# 5847                                   ['comedy']      NaN         3.8
# 5848                                           []      NaN         NaN
# 5849            ['family', 'animation', 'comedy']      1.0         7.8
#
#       imdb_votes  tmdb_popularity  tmdb_score
# 0            NaN            0.600         NaN
# 1       808582.0           40.965       8.179
# 2       107673.0           10.010       7.300
# 3       534486.0           15.461       7.811
# 4        72662.0           20.398       7.600
# ...          ...              ...         ...
# 5845        45.0            1.466         NaN
# 5846       348.0              NaN         NaN
# 5847        68.0           26.005       6.300
# 5848         NaN            1.296      10.000
# 5849        18.0            2.289      10.000
#
# [5850 rows x 12 columns]

# %%
title.isna().sum()
# Out:
# id                      0
# title                   1
# type                    0
# release_year            0
# age_certification    2619
# runtime                 0
# genres                  0
# seasons              3744
# imdb_score            482
# imdb_votes            498
# tmdb_popularity        91
# tmdb_score            311
# dtype: int64

# %% [markdown]
# #### seasons 가 tmdb_popularity와 연관 높아 지우지 않고 nan값은 0으로 보간

# %%
title['seasons']=title['seasons'].fillna(0)

# %%
title.isna().sum()
# Out:
# id                      0
# title                   1
# type                    0
# release_year            0
# age_certification    2619
# runtime                 0
# genres                  0
# seasons                 0
# imdb_score            482
# imdb_votes            498
# tmdb_popularity        91
# tmdb_score            311
# dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10,6))
netflix_corr = sns.heatmap(title.corr(), annot=True, linewidths=0.5, cmap='BuPu')
netflix_corr.set_xticklabels(netflix_corr.get_xticklabels(), rotation=45)
netflix_corr.axes.set_title('Netflix data After Data Preprocessing', fontsize=20)
# Out:
# Text(0.5, 1.0, 'Netflix data After Data Preprocessing')

# %% [markdown]
# 썡데이터 그래프

# %%
top_pop=title.sort_values('tmdb_popularity',ascending=False)
top_imbd=title.sort_values('imdb_score',ascending=False)
top_tmbd=title.sort_values('tmdb_score',ascending=False)
top_vote=title.sort_values('imdb_votes',ascending=False)

fig = plt.figure(figsize=(20,10))

plt.subplot(1,2,1)

x = top_imbd.head(10)['title']
y = top_imbd.head(10)['imdb_score']
bar = plt.bar(x, y, alpha=0.5,color='r')
plt.ylim(0, 12)

# 숫자 넣는 부분
for rect in bar:
    height = rect.get_height()
    plt.text(rect.get_x() + rect.get_width()/2.0, height, '%.1f' % height, ha='center', va='bottom', size = 12)

plt.xticks(rotation=80)
plt.title("Top10 IMDB score in Netflix",fontweight="bold")
#-----------------------------------------------------------------------
plt.subplot(1,2,2)
x = top_tmbd.head(10)['title']
y = top_tmbd.head(10)['tmdb_score']
bar = plt.bar(x, y, alpha=0.5,color='r')
plt.ylim(0, 12)

# 숫자 넣는 부분
for rect in bar:
    height = rect.get_height()
    plt.text(rect.get_x() + rect.get_width()/2.0, height, '%.1f' % height, ha='center', va='bottom', size = 12)

plt.xticks(rotation=80)
plt.title("Top10 TMDB score in Netflix",fontweight="bold")
plt.show()
#-----------------------------------------------------------------------
fig = plt.figure(figsize=(20,10))

plt.subplot(1,2,1)
x = top_pop.head(10)['title']
y = top_pop.head(10)['tmdb_popularity']
bar = plt.bar(x, y, alpha=0.5,color='r')
plt.ylim(0, 2500)

# 숫자 넣는 부분
for rect in bar:
    height = rect.get_height()
    plt.text(rect.get_x() + rect.get_width()/2.0, height, '%.d' % height, ha='center', va='bottom', size = 12)

plt.xticks(rotation=80)
plt.title("Top10 popularity score in Netflix",fontweight="bold")
#-----------------------------------------------------------------------
plt.subplot(1,2,2)
x = top_vote.head(10)['title']
y = top_vote.head(10)['imdb_votes']
bar = plt.bar(x, y, alpha=0.5,color='r')
plt.ylim(0, 2500000)

# 숫자 넣는 부분
for rect in bar:
    height = rect.get_height()
    plt.text(rect.get_x() + rect.get_width()/2.0, height, '%.d' % height, ha='center', va='bottom', size = 12)

plt.xticks(rotation=90)
plt.title("Top10 imdb votes in Netflix",fontweight="bold")

plt.tight_layout()
plt.show()

# %%
fig = plt.figure(figsize=(20,10))

plt.subplot(1,2,1)

x = top_pop.head(10)['title']
y = top_pop.head(10)['imdb_score']
bar = plt.bar(x, y, alpha=0.5,color='r')
plt.ylim(0, 10)

# 숫자 넣는 부분
for rect in bar:
    height = rect.get_height()
    plt.text(rect.get_x() + rect.get_width()/2.0, height, '%.1f' % height, ha='center', va='bottom', size = 12)

plt.xticks(rotation=80)
plt.title("Top10 IMDB score about TMDB Popularity in Netflix",fontweight="bold")
#-----------------------------------------------------------------------
plt.subplot(1,2,2)
x = top_pop.head(10)['title']
y = top_pop.head(10)['tmdb_score']
bar = plt.bar(x, y, alpha=0.5,color='r')
plt.ylim(0, 10)

# 숫자 넣는 부분
for rect in bar:
    height = rect.get_height()
    plt.text(rect.get_x() + rect.get_width()/2.0, height, '%.1f' % height, ha='center', va='bottom', size = 12)

plt.xticks(rotation=80)
plt.title("Top10 TMDB score about TMDB Popularity in Netflix",fontweight="bold")
plt.show()
#-----------------------------------------------------------------------
fig = plt.figure(figsize=(20,10))

plt.subplot(1,2,1)
x = top_vote.head(10)['title']
y = top_vote.head(10)['imdb_score']
bar = plt.bar(x, y, alpha=0.5,color='r')
plt.ylim(0, 10)

# 숫자 넣는 부분
for rect in bar:
    height = rect.get_height()
    plt.text(rect.get_x() + rect.get_width()/2.0, height, '%.1f' % height, ha='center', va='bottom', size = 12)

plt.xticks(rotation=80)
plt.title("Top10 IMDB score about IMDB votes in Netflix",fontweight="bold")
#-----------------------------------------------------------------------
plt.subplot(1,2,2)
x = top_vote.head(10)['title']
y = top_vote.head(10)['tmdb_score']
bar = plt.bar(x, y, alpha=0.5,color='r')
plt.ylim(0, 10)

# 숫자 넣는 부분
for rect in bar:
    height = rect.get_height()
    plt.text(rect.get_x() + rect.get_width()/2.0, height, '%.1f' % height, ha='center', va='bottom', size = 12)

plt.xticks(rotation=90)
plt.title("Top10 TMDB score about IMDB votes in Netflix",fontweight="bold")

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 결측치 처리

# %% [markdown]
# #### imdb_score, imdb_votes, tmdb_popularity, tmdb_score 다 값 없을 경우 제거

# %%
all_nan=(title['imdb_score'].isna()) * (title['tmdb_score'].isna())* (title['imdb_votes'].isna())* (title['tmdb_popularity'].isna())
all_nan=list(all_nan)

#4개 모두 없는 행
inde=[]

for i in range(len(all_nan)):
    if all_nan[i]==True:
        inde.append(i)
        
print(inde)
# Out:
# [577, 627, 808, 1072, 1088, 1588, 1668, 1704, 2754, 2930, 2941, 3819, 5483, 5507, 5810, 5844]
# C:\conda\lib\site-packages\pandas\core\computation\expressions.py:203: UserWarning: evaluating in Python space because the '*' operator is not supported by numexpr for the bool dtype, use '&' instead
#   warnings.warn(

# %%
title=title.drop(index=inde)
title.isna().sum()
# Out:
# id                      0
# title                   0
# type                    0
# release_year            0
# age_certification    2608
# runtime                 0
# genres                  0
# seasons                 0
# imdb_score            466
# imdb_votes            482
# tmdb_popularity        75
# tmdb_score            295
# dtype: int64

# %% [markdown]
# #### imdb_score, imdb_votes 둘 중 하나만 없을 경우 대체

# %%
t=pd.DataFrame(title['imdb_score'],title['tmdb_score'])
t
# Out:
#             imdb_score
# tmdb_score
# NaN                NaN
# 8.179              NaN
# 7.300              NaN
# 7.811              NaN
# 7.600              NaN
# ...                ...
# NaN                NaN
# NaN                NaN
# 6.300              NaN
# 10.000             7.5
# 10.000             7.5
#
# [5834 rows x 1 columns]

# %% [markdown]
# ##### 하나만 nan 값인 경우

# %%
title['imdb_score']=title['imdb_score'].fillna(title['tmdb_score'])

title['tmdb_score']=title['tmdb_score'].fillna(title['imdb_score'])

title
# Out:
#              id                                      title   type  \
# 0      ts300399        Five Came Back: The Reference Films   SHOW
# 1       tm84618                                Taxi Driver  MOVIE
# 2      tm154986                                Deliverance  MOVIE
# 3      tm127384            Monty Python and the Holy Grail  MOVIE
# 4      tm120801                            The Dirty Dozen  MOVIE
# ...         ...                                        ...    ...
# 5845  tm1014599                                  Fine Wine  MOVIE
# 5846   tm898842                                C/O Kaadhal  MOVIE
# 5847  tm1059008                                    Lokillo  MOVIE
# 5848  tm1035612  Dad Stop Embarrassing Me - The Afterparty  MOVIE
# 5849   ts271048         Mighty Little Bheem: Kite Festival   SHOW
#
#       release_year age_certification  runtime  \
# 0             1945             TV-MA       51
# 1             1976                 R      114
# 2             1972                 R      109
# 3             1975                PG       91
# 4             1967               NaN      150
# ...            ...               ...      ...
# 5845          2021               NaN      100
# 5846          2021               NaN      134
# 5847          2021               NaN       90
# 5848          2021             PG-13       37
# 5849          2021               NaN        7
#
#                                            genres  seasons  imdb_score  \
# 0                               ['documentation']      1.0         NaN
# 1                              ['drama', 'crime']      0.0         8.2
# 2     ['drama', 'action', 'thriller', 'european']      0.0         7.7
# 3                 ['fantasy', 'action', 'comedy']      0.0         8.2
# 4                               ['war', 'action']      0.0         7.7
# ...                                           ...      ...         ...
# 5845                         ['romance', 'drama']      0.0         6.8
# 5846                                    ['drama']      0.0         7.7
# 5847                                   ['comedy']      0.0         3.8
# 5848                                           []      0.0        10.0
# 5849            ['family', 'animation', 'comedy']      1.0         7.8
#
#       imdb_votes  tmdb_popularity  tmdb_score
# 0            NaN            0.600         NaN
# 1       808582.0           40.965       8.179
# 2       107673.0           10.010       7.300
# 3       534486.0           15.461       7.811
# 4        72662.0           20.398       7.600
# ...          ...              ...         ...
# 5845        45.0            1.466       6.800
# 5846       348.0              NaN       7.700
# 5847        68.0           26.005       6.300
# 5848         NaN            1.296      10.000
# 5849        18.0            2.289      10.000
#
# [5834 rows x 12 columns]

# %% [markdown]
# #### 둘 다 nan 인경우는 삭제

# %%
title=title.dropna(subset=['imdb_score','tmdb_score']).reset_index(drop=True)
title
# Out:
#              id                                      title   type  \
# 0       tm84618                                Taxi Driver  MOVIE
# 1      tm154986                                Deliverance  MOVIE
# 2      tm127384            Monty Python and the Holy Grail  MOVIE
# 3      tm120801                            The Dirty Dozen  MOVIE
# 4       ts22164               Monty Python's Flying Circus   SHOW
# ...         ...                                        ...    ...
# 5757  tm1014599                                  Fine Wine  MOVIE
# 5758   tm898842                                C/O Kaadhal  MOVIE
# 5759  tm1059008                                    Lokillo  MOVIE
# 5760  tm1035612  Dad Stop Embarrassing Me - The Afterparty  MOVIE
# 5761   ts271048         Mighty Little Bheem: Kite Festival   SHOW
#
#       release_year age_certification  runtime  \
# 0             1976                 R      114
# 1             1972                 R      109
# 2             1975                PG       91
# 3             1967               NaN      150
# 4             1969             TV-14       30
# ...            ...               ...      ...
# 5757          2021               NaN      100
# 5758          2021               NaN      134
# 5759          2021               NaN       90
# 5760          2021             PG-13       37
# 5761          2021               NaN        7
#
#                                            genres  seasons  imdb_score  \
# 0                              ['drama', 'crime']      0.0         8.2
# 1     ['drama', 'action', 'thriller', 'european']      0.0         7.7
# 2                 ['fantasy', 'action', 'comedy']      0.0         8.2
# 3                               ['war', 'action']      0.0         7.7
# 4                          ['comedy', 'european']      4.0         8.8
# ...                                           ...      ...         ...
# 5757                         ['romance', 'drama']      0.0         6.8
# 5758                                    ['drama']      0.0         7.7
# 5759                                   ['comedy']      0.0         3.8
# 5760                                           []      0.0        10.0
# 5761            ['family', 'animation', 'comedy']      1.0         7.8
#
#       imdb_votes  tmdb_popularity  tmdb_score
# 0       808582.0           40.965       8.179
# 1       107673.0           10.010       7.300
# 2       534486.0           15.461       7.811
# 3        72662.0           20.398       7.600
# 4        73424.0           17.617       8.306
# ...          ...              ...         ...
# 5757        45.0            1.466       6.800
# 5758       348.0              NaN       7.700
# 5759        68.0           26.005       6.300
# 5760         NaN            1.296      10.000
# 5761        18.0            2.289      10.000
#
# [5762 rows x 12 columns]

# %%
title.isna().sum()
# Out:
# id                      0
# title                   0
# type                    0
# release_year            0
# age_certification    2572
# runtime                 0
# genres                  0
# seasons                 0
# imdb_score              0
# imdb_votes            410
# tmdb_popularity        75
# tmdb_score              0
# dtype: int64

# %% [markdown]
# #### 그래프 그리기

# %%
top_pop=title.sort_values('tmdb_popularity',ascending=False)
top_imbd=title.sort_values('imdb_score',ascending=False)
top_tmbd=title.sort_values('tmdb_score',ascending=False)
top_vote=title.sort_values('imdb_votes',ascending=False)

fig = plt.figure(figsize=(20,10))

plt.subplot(1,2,1)

x = top_imbd.head(10)['title']
y = top_imbd.head(10)['imdb_score']
bar = plt.bar(x, y, alpha=0.5,color='r')
plt.ylim(0, 12)

# 숫자 넣는 부분
for rect in bar:
    height = rect.get_height()
    plt.text(rect.get_x() + rect.get_width()/2.0, height, '%.1f' % height, ha='center', va='bottom', size = 12)

plt.xticks(rotation=80)
plt.title("Top10 IMDB score in Netflix",fontweight="bold")
#-----------------------------------------------------------------------
plt.subplot(1,2,2)
x = top_tmbd.head(10)['title']
y = top_tmbd.head(10)['tmdb_score']
bar = plt.bar(x, y, alpha=0.5,color='r')
plt.ylim(0, 12)

# 숫자 넣는 부분
for rect in bar:
    height = rect.get_height()
    plt.text(rect.get_x() + rect.get_width()/2.0, height, '%.1f' % height, ha='center', va='bottom', size = 12)

plt.xticks(rotation=80)
plt.title("Top10 TMDB score in Netflix",fontweight="bold")
plt.show()
#-----------------------------------------------------------------------
fig = plt.figure(figsize=(20,10))

plt.subplot(1,2,1)
x = top_pop.head(10)['title']
y = top_pop.head(10)['tmdb_popularity']
bar = plt.bar(x, y, alpha=0.5,color='r')
plt.ylim(0, 2500)

# 숫자 넣는 부분
for rect in bar:
    height = rect.get_height()
    plt.text(rect.get_x() + rect.get_width()/2.0, height, '%.d' % height, ha='center', va='bottom', size = 12)

plt.xticks(rotation=80)
plt.title("Top10 popularity score in Netflix",fontweight="bold")
#-----------------------------------------------------------------------
plt.subplot(1,2,2)
x = top_vote.head(10)['title']
y = top_vote.head(10)['imdb_votes']
bar = plt.bar(x, y, alpha=0.5,color='r')
plt.ylim(0, 2500000)

# 숫자 넣는 부분
for rect in bar:
    height = rect.get_height()
    plt.text(rect.get_x() + rect.get_width()/2.0, height, '%.d' % height, ha='center', va='bottom', size = 12)

plt.xticks(rotation=90)
plt.title("Top10 imdb votes in Netflix",fontweight="bold")

plt.tight_layout()
plt.show()

# %%
fig = plt.figure(figsize=(20,10))

plt.subplot(1,2,1)

x = top_pop.head(10)['title']
y = top_pop.head(10)['imdb_score']
bar = plt.bar(x, y, alpha=0.5,color='r')
plt.ylim(0, 10)

# 숫자 넣는 부분
for rect in bar:
    height = rect.get_height()
    plt.text(rect.get_x() + rect.get_width()/2.0, height, '%.1f' % height, ha='center', va='bottom', size = 12)

plt.xticks(rotation=80)
plt.title("Top10 IMDB score about TMDB Popularity in Netflix",fontweight="bold")
#-----------------------------------------------------------------------
plt.subplot(1,2,2)
x = top_pop.head(10)['title']
y = top_pop.head(10)['tmdb_score']
bar = plt.bar(x, y, alpha=0.5,color='r')
plt.ylim(0, 10)

# 숫자 넣는 부분
for rect in bar:
    height = rect.get_height()
    plt.text(rect.get_x() + rect.get_width()/2.0, height, '%.1f' % height, ha='center', va='bottom', size = 12)

plt.xticks(rotation=80)
plt.title("Top10 TMDB score about TMDB Popularity in Netflix",fontweight="bold")
plt.show()
#-----------------------------------------------------------------------
fig = plt.figure(figsize=(20,10))

plt.subplot(1,2,1)
x = top_vote.head(10)['title']
y = top_vote.head(10)['imdb_score']
bar = plt.bar(x, y, alpha=0.5,color='r')
plt.ylim(0, 10)

# 숫자 넣는 부분
for rect in bar:
    height = rect.get_height()
    plt.text(rect.get_x() + rect.get_width()/2.0, height, '%.1f' % height, ha='center', va='bottom', size = 12)

plt.xticks(rotation=80)
plt.title("Top10 IMDB score about IMDB votes in Netflix",fontweight="bold")
#-----------------------------------------------------------------------
plt.subplot(1,2,2)
x = top_vote.head(10)['title']
y = top_vote.head(10)['tmdb_score']
bar = plt.bar(x, y, alpha=0.5,color='r')
plt.ylim(0, 10)

# 숫자 넣는 부분
for rect in bar:
    height = rect.get_height()
    plt.text(rect.get_x() + rect.get_width()/2.0, height, '%.1f' % height, ha='center', va='bottom', size = 12)

plt.xticks(rotation=90)
plt.title("Top10 TMDB score about IMDB votes in Netflix",fontweight="bold")

plt.tight_layout()
plt.show()
